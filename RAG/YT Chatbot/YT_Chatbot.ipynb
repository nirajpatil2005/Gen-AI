# %%
# !pip install langchain_groq
# Out:
# Requirement already satisfied: langchain_groq in /usr/local/lib/python3.11/dist-packages (0.3.6)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.68 in /usr/local/lib/python3.11/dist-packages (from langchain_groq) (0.3.72)
# Requirement already satisfied: groq<1,>=0.29.0 in /usr/local/lib/python3.11/dist-packages (from langchain_groq) (0.30.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from groq<1,>=0.29.0->langchain_groq) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from groq<1,>=0.29.0->langchain_groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from groq<1,>=0.29.0->langchain_groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from groq<1,>=0.29.0->langchain_groq) (2.11.7)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from groq<1,>=0.29.0->langchain_groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /usr/local/lib/python3.11/dist-packages (from groq<1,>=0.29.0->langchain_groq) (4.14.1)
# Requirement already satisfied: langsmith>=0.3.45 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.68->langchain_groq) (0.4.8)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.68->langchain_groq) (8.5.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.68->langchain_groq) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.68->langchain_groq) (6.0.2)
# Requirement already satisfied: packaging>=23.2 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.68->langchain_groq) (25.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.5.0->groq<1,>=0.29.0->langchain_groq) (3.10)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->groq<1,>=0.29.0->langchain_groq) (2025.7.14)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->groq<1,>=0.29.0->langchain_groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1,>=0.29.0->langchain_groq) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.11/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.68->langchain_groq) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.68->langchain_groq) (3.11.1)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.68->langchain_groq) (2.32.3)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.68->langchain_groq) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.68->langchain_groq) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->groq<1,>=0.29.0->langchain_groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->groq<1,>=0.29.0->langchain_groq) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->groq<1,>=0.29.0->langchain_groq) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.68->langchain_groq) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.68->langchain_groq) (2.5.0)

# %%
# !pip install -q youtube-transcript-api langchain-community langchain-openai \
               faiss-cpu tiktoken python-dotenv

# %%
pip install langchain_huggingface langchain_community langchain_text_splitters
# Out:
# Requirement already satisfied: langchain_huggingface in /usr/local/lib/python3.11/dist-packages (0.3.1)
# Requirement already satisfied: langchain_community in /usr/local/lib/python3.11/dist-packages (0.3.27)
# Requirement already satisfied: langchain_text_splitters in /usr/local/lib/python3.11/dist-packages (0.3.9)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.70 in /usr/local/lib/python3.11/dist-packages (from langchain_huggingface) (0.3.72)
# Requirement already satisfied: tokenizers>=0.19.1 in /usr/local/lib/python3.11/dist-packages (from langchain_huggingface) (0.21.2)
# Requirement already satisfied: huggingface-hub>=0.33.4 in /usr/local/lib/python3.11/dist-packages (from langchain_huggingface) (0.34.1)
# Requirement already satisfied: langchain<1.0.0,>=0.3.26 in /usr/local/lib/python3.11/dist-packages (from langchain_community) (0.3.27)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.11/dist-packages (from langchain_community) (2.0.41)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.11/dist-packages (from langchain_community) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.11/dist-packages (from langchain_community) (6.0.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.11/dist-packages (from langchain_community) (3.12.14)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from langchain_community) (8.5.0)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /usr/local/lib/python3.11/dist-packages (from langchain_community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /usr/local/lib/python3.11/dist-packages (from langchain_community) (2.10.1)
# Requirement already satisfied: langsmith>=0.1.125 in /usr/local/lib/python3.11/dist-packages (from langchain_community) (0.4.8)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from langchain_community) (0.4.1)
# Requirement already satisfied: numpy>=1.26.2 in /usr/local/lib/python3.11/dist-packages (from langchain_community) (2.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.20.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.11/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (0.9.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.33.4->langchain_huggingface) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.33.4->langchain_huggingface) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.33.4->langchain_huggingface) (25.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.33.4->langchain_huggingface) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.33.4->langchain_huggingface) (4.14.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.33.4->langchain_huggingface) (1.1.5)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.11/dist-packages (from langchain<1.0.0,>=0.3.26->langchain_community) (2.11.7)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.70->langchain_huggingface) (1.33)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.1.125->langchain_community) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.1.125->langchain_community) (3.11.1)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.1.125->langchain_community) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.1.125->langchain_community) (0.23.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain_community) (1.1.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain_community) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain_community) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain_community) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain_community) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain_community) (2025.7.14)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from SQLAlchemy<3,>=1.4->langchain_community) (3.2.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith>=0.1.125->langchain_community) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith>=0.1.125->langchain_community) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.1.125->langchain_community) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.11/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.70->langchain_huggingface) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.26->langchain_community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.26->langchain_community) (2.33.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community) (1.1.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.1.125->langchain_community) (1.3.1)

# %%
from langchain_huggingface import ChatHuggingFace,HuggingFaceEndpoint
from dotenv import load_dotenv
import os
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
load_dotenv()

hf_token=os.getenv("HF_TOKEN")

llm = HuggingFaceEndpoint(
    repo_id="moonshotai/Kimi-K2-Instruct",  # Use the correct model repo_id
    task="text-generation",  # You can adjust this based on your model task
    model_kwargs={"headers": {"Authorization": f"Bearer {hf_token}"}}
)

model=ChatHuggingFace(llm=llm)

# %%
from langchain_groq import ChatGroq
import os

groq_token = os.getenv("test_groq")
llm = ChatGroq(
    groq_api_key=groq_token,
    model_name="meta-llama/llama-4-scout-17b-16e-instruct"
)

# Use llm directly - no need for ChatHuggingFace wrapper
response = llm.invoke("Your prompt here")

# %%
from youtube_transcript_api import YouTubeTranscriptApi

api = YouTubeTranscriptApi()

# List available transcripts with types, dialects, and translation support
transcript_list = api.list("Gfr50f6ZBvo")

for t in transcript_list:
    print(
        f"- {t.language_code} "
        f"({'manual' if not t.is_generated else 'auto-generated'}) "
        f"{'[translatable]' if t.is_translatable else ''}"
    )
# Out:
# - en (auto-generated) [translatable]

# %%
from youtube_transcript_api import YouTubeTranscriptApi
print(dir(YouTubeTranscriptApi))  # Should list 'get_transcript'
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'fetch', 'list']

# %%
from youtube_transcript_api import YouTubeTranscriptApi

video_id = "Gfr50f6ZBvo"  # Example video

# Create an instance first
api = YouTubeTranscriptApi()

# Now call fetch()
transcript = api.fetch(video_id, languages=['en'])
print(transcript)
# Out:
# FetchedTranscript(snippets=[FetchedTranscriptSnippet(text='the following is a conversation with', start=0.08, duration=3.44), FetchedTranscriptSnippet(text='demus hasabis', start=1.76, duration=4.96), FetchedTranscriptSnippet(text='ceo and co-founder of deepmind', start=3.52, duration=5.119), FetchedTranscriptSnippet(text='a company that has published and builds', start=6.72, duration=4.48), FetchedTranscriptSnippet(text='some of the most incredible artificial', start=8.639, duration=4.561), FetchedTranscriptSnippet(text='intelligence systems in the history of', start=11.2, duration=4.8), FetchedTranscriptSnippet(text='computing including alfred zero that', start=13.2, duration=3.68), FetchedTranscriptSnippet(text='learned', start=16.0, duration=2.96), FetchedTranscriptSnippet(text='all by itself to play the game of gold', start=16.88, duration=4.559), FetchedTranscriptSnippet(text='better than any human in the world and', start=18.96, duration=5.6), FetchedTranscriptSnippet(text='alpha fold two that solved protein', start=21.439, duration=4.241), FetchedTranscriptSnippet(text='folding', start=24.56, duration=4.16), FetchedTranscriptSnippet(text='both tasks considered nearly impossible', start=25.68, duration=5.439), FetchedTranscriptSnippet(text='for a very long time', start=28.72, duration=4.4), FetchedTranscriptSnippet(text='demus is widely considered to be one of', start=31.119, duration=4.481), FetchedTranscriptSnippet(text='the most brilliant and impactful humans', start=33.12, duration=4.0), FetchedTranscriptSnippet(text='in the history of artificial', start=35.6, duration=4.24), FetchedTranscriptSnippet(text='intelligence and science and engineering', start=37.12, duration=4.0), FetchedTranscriptSnippet(text='in general', start=39.84, duration=3.92), FetchedTranscriptSnippet(text='this was truly an honor and a pleasure', start=41.12, duration=4.959), FetchedTranscriptSnippet(text='for me to finally sit down with him for', start=43.76, duration=4.799), FetchedTranscriptSnippet(text="this conversation and i'm sure we will", start=46.079, duration=5.361), FetchedTranscriptSnippet(text='talk many times again in the future', start=48.559, duration=4.721), FetchedTranscriptSnippet(text='this is the lex friedman podcast to', start=51.44, duration=4.0), FetchedTranscriptSnippet(text='support it please check out our sponsors', start=53.28, duration=4.959), FetchedTranscriptSnippet(text='in the description and now dear friends', start=55.44, duration=4.16), FetchedTranscriptSnippet(text="here's demis", start=58.239, duration=3.201), FetchedTranscriptSnippet(text='hassabis', start=59.6, duration=3.36), FetchedTranscriptSnippet(text="let's start with a bit of a personal", start=61.44, duration=2.48), FetchedTranscriptSnippet(text='question', start=62.96, duration=3.839), FetchedTranscriptSnippet(text='am i an ai program you wrote to', start=63.92, duration=4.8), FetchedTranscriptSnippet(text='interview people until i get good enough', start=66.799, duration=4.161), FetchedTranscriptSnippet(text='to interview you', start=68.72, duration=4.24), FetchedTranscriptSnippet(text="well i'll be impressed if if you were", start=70.96, duration=3.839), FetchedTranscriptSnippet(text="i'd be impressed by myself if you were i", start=72.96, duration=3.44), FetchedTranscriptSnippet(text="don't think we're quite up to that yet", start=74.799, duration=3.921), FetchedTranscriptSnippet(text="but uh maybe you're from the future lex", start=76.4, duration=4.48), FetchedTranscriptSnippet(text='if you did would you tell me is that is', start=78.72, duration=3.84), FetchedTranscriptSnippet(text='that a good thing to tell a language', start=80.88, duration=4.08), FetchedTranscriptSnippet(text="model that's tasked with interviewing", start=82.56, duration=5.199), FetchedTranscriptSnippet(text="that it is in fact um ai maybe we're in", start=84.96, duration=5.28), FetchedTranscriptSnippet(text='a kind of meta turing test uh probably', start=87.759, duratio ...

# %%
# Assuming 'transcript' is your FetchedTranscript object
transcript_dict_list = [
    {
        "text": snippet.text,
        "start": snippet.start,
        "duration": snippet.duration
    }
    for snippet in transcript.snippets
]

# Print the first 5 entries to verify
print(transcript_dict_list[:5])
# Out:
# [{'text': 'the following is a conversation with', 'start': 0.08, 'duration': 3.44}, {'text': 'demus hasabis', 'start': 1.76, 'duration': 4.96}, {'text': 'ceo and co-founder of deepmind', 'start': 3.52, 'duration': 5.119}, {'text': 'a company that has published and builds', 'start': 6.72, 'duration': 4.48}, {'text': 'some of the most incredible artificial', 'start': 8.639, 'duration': 4.561}]

# %%
import json
json_output = json.dumps(transcript_dict_list, indent=2)
print(json_output)
# Out:
# [
#   {
#     "text": "the following is a conversation with",
#     "start": 0.08,
#     "duration": 3.44
#   },
#   {
#     "text": "demus hasabis",
#     "start": 1.76,
#     "duration": 4.96
#   },
#   {
#     "text": "ceo and co-founder of deepmind",
#     "start": 3.52,
#     "duration": 5.119
#   },
#   {
#     "text": "a company that has published and builds",
#     "start": 6.72,
#     "duration": 4.48
#   },
#   {
#     "text": "some of the most incredible artificial",
#     "start": 8.639,
#     "duration": 4.561
#   },
#   {
#     "text": "intelligence systems in the history of",
#     "start": 11.2,
#     "duration": 4.8
#   },
#   {
#     "text": "computing including alfred zero that",
#     "start": 13.2,
#     "duration": 3.68
#   },
#   {
#     "text": "learned",
#     "start": 16.0,
#     "duration": 2.96
#   },
#   {
#     "text": "all by itself to play the game of gold",
#     "start": 16.88,
#     "duration": 4.559
#   },
#   {
#     "text": "better than any human in the world and",
#     "start": 18.96,
#     "duration": 5.6
#   },
#   {
#     "text": "alpha fold two that solved protein",
#     "start": 21.439,
#     "duration": 4.241
#   },
#   {
#     "text": "folding",
#     "start": 24.56,
#     "duration": 4.16
#   },
#   {
#     "text": "both tasks considered nearly impossible",
#     "start": 25.68,
#     "duration": 5.439
#   },
#   {
#     "text": "for a very long time",
#     "start": 28.72,
#     "duration": 4.4
#   },
#   {
#     "text": "demus is widely considered to be one of",
#     "start": 31.119,
#     "duration": 4.481
#   },
#   {
#     "text": "the most brilliant and impactful humans",
#     "start": 33.12,
#     "duration": 4.0
#   },
#   {
#     "text": "in the history of artificial",
#     "start": 35.6,
#     "duration": 4.24
#   },
#   {
#     "text": "intelligence and science and engineering",
#     "start": 37.12,
#     "duration": 4.0
#   },
#   {
#     "text": "in general",
#     "start": 39.84,
#     "duration": 3.92
#   },
#   {
#     "text": "this was truly an honor and a pleasure",
#     "start": 41.12,
#     "duration": 4.959
#   },
#   {
#     "text": "for me to finally sit down with him for",
#     "start": 43.76,
#     "duration": 4.799
#   },
#   {
#     "text": "this conversation and i'm sure we will",
#     "start": 46.079,
#     "duration": 5.361
#   },
#   {
#     "text": "talk many times again in the future",
#     "start": 48.559,
#     "duration": 4.721
#   },
#   {
#     "text": "this is the lex friedman podcast to",
#     "start": 51.44,
#     "duration": 4.0
#   },
#   {
#     "text": "support it please check out our sponsors",
#     "start": 53.28,
#     "duration": 4.959
#   },
#   {
#     "text": "in the description and now dear friends",
#     "start": 55.44,
#     "duration": 4.16
#   },
#   {
#     "text": "here's demis",
#     "start": 58.239,
#     "duration": 3.201
#   },
#   {
#     "text": "hassabis",
#     "start": 59.6,
#     "duration": 3.36
#   },
#   {
#     "text": "let's start with a bit of a personal",
#     "start": 61.44,
#     "duration": 2.48
#   },
#   {
#     "text": "question",
#     "start": 62.96,
#     "duration": 3.839
#   },
#   {
#     "text": "am i an ai program you wrote to",
#     "start": 63.92,
#     "duration": 4.8
#   },
#   {
#     "text": "interview people until i get good enough",
#     "start": 66.799,
#     "duration": 4.161
#   },
#   {
#     "text": "to interview you",
#     "start": 68.72,
#     "duration": 4.24
#   },
#   {
#     "text": "well i'll be impressed if if you were",
#     "start": 70.96,
#     "duration": 3.839
#   },
#   {
#     "text": "i'd be impressed by myself if you were i",
#     "start": 72.96,
#     "duration": 3.44
#   },
#   {
#     "text": "don't think we're quite up to that yet",
#     "start": 74.799,
#     "duration": 3.921
#   },
#   {
#     "text": "but uh maybe you're from the future lex",
#     "start": 76.4,
#     "duration": 4.48
#   },
#   {
#     "text": "if you did would you tell me is that is",
#     "start": 78.72,
#     "duration": 3.84
#   },
#   {
#     "text": "that a good thing to tell a language",
#     "start": 80.88,
#     "duration": 4.08
#   },
#   {
#     "text": "model that's tasked with interviewing",
#     "start": 82.56,
#     "duration": 5.199
#   },
#   {
#     "text": "that it is in fact um ai maybe we're in",
#     "start": 84.96,
#     "duration": 5.28
#   },
#   {
#     "text": "a kind of meta turing test uh probably",
#     "start": 87.759,
#     "duration": 4.081
#   },
#   {
#     "text": "probably it would be a good idea not to",
#     "start": 90.24,
#     "duration": 2.96
#   },
#   {
#     "text": "tell you so it doesn't change your",
#     "start": 91.84,
#     "duration": 2.88
#   },
#   {
#     "text": "behavior right this is a kind of",
#     "start": 93.2,
#     "duration": 3.2
#   },
#   {
#     "text": "heisenberg uncertainty principle",
#     "start": 94.72,
#     "duration": 3.359
#   },
#   {
#     "text": "situation if i told you you behave",
#     "start": 96.4,
#     "duration": 3.12
#   },
#   {
#     "text": "differently yeah maybe that's what's",
#     "start": 98.079,
#     "duration": 3.201
#   },
#   {
#     "text": "happening with us of course this is a",
#     "start": 99.52,
#     "duration": 4.0
#   },
#   {
#     "text": "benchmark from the future where they",
#     "start": 101.28,
#     "duration": 6.56
#   },
#   {
#     "text": "replay 2022 as a year before ais were",
#     "start": 103.52,
#     "duration": 7.36
#   },
#   {
#     "text": "good enough yet and now we want to see",
#     "start": 107.84,
#     "duration": 5.919
#   },
#   {
#     "text": "is it going to pass exactly",
#     "start": 110.88,
#     "duration": 4.559
#   },
#   {
#     "text": "if i was such a",
#     "start": 113.759,
#     "duration": 3.36
#   },
#   {
#     "text": "program would you be able to tell do you",
#     "start": 115.439,
#     "duration": 4.481
#   },
#   {
#     "text": "think so to the touring test question",
#     "start": 117.119,
#     "duration": 5.921
#   },
#   {
#     "text": "you've talked about",
#     "start": 119.92,
#     "duration": 3.12
#   },
#   {
#     "text": "the benchmark for solving intelligence",
#     "start": 123.2,
#     "duration": 3.919
#   },
#   {
#     "text": "what would be the impressive thing",
#     "start": 125.68,
#     "duration": 2.96
#   },
#   {
#     "text": "you've talked about winning a nobel",
#     "start": 127.119,
#     "duration": 4.161
#   },
#   {
#     "text": "prize in a system winning a nobel prize",
#     "start": 128.64,
#     "duration": 4.72
#   },
#   {
#     "text": "but i still return to the touring test",
#     "start": 131.28,
#     "duration": 3.76
#   },
#   {
#     "text": "as a compelling test the spirit of the",
#     "start": 133.36,
#     "duration": 3.76
#   },
#   {
#     "text": "touring test is a compelling test",
#     "start": 135.04,
#     "duration": 3.76
#   },
#   {
#     "text": "yeah the turing test of course it's been",
#     "start": 137.12,
#     "duration": 3.52
#   },
#   {
#     "text": "unbelievably influential and turing's",
#     "start": 138.8,
#     "duration": 4.24
#   },
#   {
#     "text": "one of my all-time heroes but i think if",
#     "start": 140.64,
#     "duration": 4.239
#   },
#   {
#     "text": "you look back at the 1950 papers",
#     "start": 143.04,
#     "duration": 3.839
#   },
#   {
#     "text": "original paper and read the original",
#     "start": 144.879,
#     "duration": 4.0
#   },
#   {
#     "text": "you'll see i don't think he meant it to",
#     "start": 146.879,
#     "duration": 4.321
#   },
#   {
#     "text": "be a rigorous formal test i think it was",
#     "start": 148.879,
#     "duration": 4.161
#   },
#   {
#     "text": "more like a thought experiment almost a",
#     "start": 151.2,
#     "duration": 3.52
#   },
#   {
#     "text": "bit of philosophy he was writing if you",
#     "start": 153.04,
#     "duration": 3.52
#   },
#   {
#     "text": "look at the style of the paper and you",
#     "start": 154.72,
#     "duration": 3.28
#   },
#   {
#     "text": "can see he didn't specify it very",
#     "start": 156.56,
#     "duration": 3.52
#   },
#   {
#     "text": "rigorously so for example he didn't",
#     "start": 158.0,
#     "duration": 4.879
#   },
#   {
#     "text": "specify the knowledge that the expert or",
#     "start": 160.08,
#     "duration": 5.439
#   },
#   {
#     "text": "judge would have um not you know how",
#     "start": 162.879,
#     "duration": 4.801
#   },
#   {
#     "text": "much time would they have to investigate",
#     "start": 165.519,
#     "duration": 4.0
#   },
#   {
#     "text": "this so these important parameters if",
#     "start": 167.68,
#     "duration": 4.48
#   },
#   {
#     "text": "you were gonna make it uh a true sort of",
#     "start": 169.519,
#     "duration": 3.921
#   },
#   {
#     "text": "formal test",
#     "start": 172.16,
#     "duration": 4.32
#   },
#   {
#     "text": "um and you know some by some measures",
#     "start": 173.44,
#     "duration": 4.879
#   },
#   {
#     "text": "people claimed the turing test passed",
#     "start": 176.48,
#     "duration": 3.36
#   },
#   {
#     "text": "several you know a decade ago i remember",
#     "start": 178.319,
#     "duration": 3.2
#   },
#   {
#     "text": "someone claiming that with a with a kind",
#     "start": 179.84,
#     "duration": 4.56
#   },
#   {
#     "text": "of very bog standard normal uh",
#     "start": 181.519,
#     "duration": 5.44
#   },
#   {
#     "text": "logic model um because they pretended it",
#     "start": 184.4,
#     "duration": 5.199
#   },
#   {
#     "text": "was a it was a kid so the the judges",
#     "start": 186.959,
#     "duration": 4.721
#   },
#   {
#     "text": "thought that the machine you know was",
#     "start": 189.599,
#     "duration": 5.121
#   },
#   {
#     "text": "was a was a child so um that would be",
#     "start": 191.68,
#     "duration": 5.52
#   },
#   {
#     "text": "very different from an expert ai person",
#     "start": 194.72,
#     "duration": 4.32
#   },
#   {
#     "text": "uh interrogating a machine and knowing",
#     "start": 197.2,
#     "duration": 5.119
#   },
#   {
#     "text": "how it was built and so on so i think um",
#     "start": 199.04,
#     "duration": 4.64
#   },
#   {
#     "text": "you know we should probably move away",
#     "start": 202.319,
#     "duration": 4.081
#   },
#   {
#     "text": "from that as a formal test and move more",
#     "start": 203.68,
#     "duration": 5.839
#   },
#   {
#     "text": "towards a general test where we test the",
#     "start": 206.4,
#     "duration": 5.759
#   },
#   {
#     "text": "ai capabilities on a range of tasks and",
#     "start": 209.519,
#     "duration": 5.121
#   },
#   {
#     "text": "see if it reaches human level or above",
#     "start": 212.159,
#     "duration": 5.121
#   },
#   {
#     "text": "performance on maybe thousands perhaps",
#     "start": 214.64,
#     "duration": 4.64
#   },
#   {
#     "text": "even millions of tasks eventually and",
#     "start": 217.28,
#     "duration": 4.56
#   },
#   {
#     "text": "cover the entire sort of cognitive space",
#     "start": 219.28,
#     "duration": 4.08
#   },
#   {
#     "text": "so i think",
#     "start": 221.84,
#     "duration": 3.119
#   },
#   {
#     "text": "for its time it was an amazing thought",
#     "start": 223.36,
#     "duration": 3.92
#   },
#   {
#     "text": "experiment and also 1950s obviously it",
#     "start": 224.959,
#     "duration": 4.321
#   },
#   {
#     "text": "was barely the dawn of the computer age",
#     "start": 227.28,
#     "duration": 4.08
#   },
#   {
#     "text": "so of course he only thought about text",
#     "start": 229.28,
#     "duration": 4.239
#   },
#   {
#     "text": "and now um we have a lot more different",
#     "start": 231.36,
#     "duration": 3.12
#   },
#   {
#     "text": "inputs",
#     "start": 233.519,
#     "duration": 3.44
#   },
#   {
#     "text": "so yeah maybe the better thing to test",
#     "start": 234.48,
#     "duration": 4.319
#   },
#   {
#     "text": "is the generalizability so across",
#     "start": 236.959,
#     "duration": 4.0
#   },
#   {
#     "text": "multiple tasks but i think it's also",
#     "start": 238.799,
#     "duration": 5.761
#   },
#   {
#     "text": "possible as as systems like god show",
#     "start": 240.959,
#     "duration": 4.56
#   },
#   {
#     "text": "that",
#     "start": 244.56,
#     "duration": 2.879
#   },
#   {
#     "text": "eventually that might map right back to",
#     "start": 245.519,
#     "duration": 3.681
#   },
#   {
#     "text": "language so you might be able to",
#     "start": 247.439,
#     "duration": 4.08
#   },
#   {
#     "text": "demonstrate your ability to generalize",
#     "start": 249.2,
#     "duration": 3.92
#   },
#   {
#     "text": "across tasks",
#     "start": 251.519,
#     "duration": 3.841
#   },
#   {
#     "text": "by then communicating your ability to",
#     "start": 253.12,
#     "duration": 4.399
#   },
#   {
#     "text": "generalize across tasks which is kind of",
#     "start": 255.36,
#     "duration": 3.68
#   },
#   {
#     "text": "what we do through conversation anyway",
#     "start": 257.519,
#     "duration": 3.201
#   },
#   {
#     "text": "when we jump around",
#     "start": 259.04,
#     "duration": 3.52
#   },
#   {
#     "text": "ultimately what's in there in that",
#     "start": 260.72,
#     "duration": 4.24
#   },
#   {
#     "text": "conversation is not just you moving",
#     "start": 262.56,
#     "duration": 4.32
#   },
#   {
#     "text": "around knowledge",
#     "start": 264.96,
#     "duration": 4.16
#   },
#   {
#     "text": "it's you moving around like these",
#     "start": 266.88,
#     "duration": 4.879
#   },
#   {
#     "text": "entirely different modalities of",
#     "start": 269.12,
#     "duration": 5.84
#   },
#   {
#     "text": "understanding that ultimately map to",
#     "start": 271.759,
#     "duration": 5.121
#   },
#   {
#     "text": "your ability to",
#     "start": 274.96,
#     "duration": 4.48
#   },
#   {
#     "text": "to uh operate successfully in all these",
#     "start": 276.88,
#     "duration": 5.599
#   },
#   {
#     "text": "domains which you can think of as tasks",
#     "start": 279.44,
#     "duration": 5.52
#   },
#   {
#     "text": "yeah i think certainly we as humans use",
#     "start": 282.479,
#     "duration": 4.961
#   },
#   {
#     "text": "language as our main generalization",
#     "start": 284.96,
#     "duration": 5.04
#   },
#   {
#     "text": "communication tool so i think we end up",
#     "start": 287.44,
#     "duration": 4.88
#   },
#   {
#     "text": "thinking in language and expressing our",
#     "start": 290.0,
#     "duration": 4.96
#   },
#   {
#     "text": "solutions in language um so it's going",
#     "start": 292.32,
#     "duration": 4.08
#   },
#   {
#     "text": "to be very powerful",
#     "start": 294.96,
#     "duration": 5.12
#   },
#   {
#     "text": "uh uh mode in which to uh explain you",
#     "start": 296.4,
#     "duration": 5.2
#   },
#   {
#     "text": "know the system to explain what it's",
#     "start": 300.08,
#     "duration": 4.8
#   },
#   {
#     "text": "doing um but i don't think it's the only",
#     "start": 301.6,
#     "duration": 6.56
#   },
#   {
#     "text": "uh uh modality that matters so i think",
#     "start": 304.88,
#     "duration": 4.72
#   },
#   {
#     "text": "there's gonna be a lot of you know",
#     "start": 308.16,
#     "duration": 2.72
#   },
#   {
#     "text": "there's there's a lot of different ways",
#     "start": 309.6,
#     "duration": 4.24
#   },
#   {
#     "text": "to express uh capabilities uh other than",
#     "start": 310.88,
#     "duration": 4.56
#   },
#   {
#     "text": "just language",
#     "start": 313.84,
#     "duration": 2.88
#   },
#   {
#     "text": "yeah visual",
#     "start": 315.44,
#     "duration": 4.479
#   },
#   {
#     "text": "robotics body language",
#     "start": 316.72,
#     "duration": 4.319
#   },
#   {
#     "text": "um",
#     "start": 319.919,
#     "duration": 3.041
#   },
#   {
#     "text": "yeah action is the interactive aspect of",
#     "start": 321.039,
#     "duration": 3.761
#   },
#   {
#     "text": "all that that's all part of it but",
#     "start": 322.96,
#     "duration": 3.28
#   },
#   {
#     "text": "what's interesting with gato is that",
#     "start": 324.8,
#     "duration": 4.08
#   },
#   {
#     "text": "it's a it's it's it's sort of pushing",
#     "start": 326.24,
#     "duration": 4.48
#   },
#   {
#     "text": "prediction to the maximum in terms of",
#     "start": 328.88,
#     "duration": 3.84
#   },
#   {
#     "text": "like you know mapping arbitrary",
#     "start": 330.72,
#     "duration": 4.08
#   },
#   {
#     "text": "sequences to other sequences and sort of",
#     "start": 332.72,
#     "duration": 3.36
#   },
#   {
#     "text": "just predicting what's going to happen",
#     "start": 334.8,
#     "duration": 3.839
#   },
#   {
#     "text": "next so prediction seems to be",
#     "start": 336.08,
#     "duration": 4.88
#   },
#   {
#     "text": "fundamental to intelligence",
#     "start": 338.639,
#     "duration": 4.161
#   },
#   {
#     "text": "and what you're predicting",
#     "start": 340.96,
#     "duration": 4.0
#   },
#   {
#     "text": "doesn't so much matter yeah it seems",
#     "start": 342.8,
#     "duration": 3.839
#   },
#   {
#     "text": "like you can generalize that quite well",
#     "start": 344.96,
#     "duration": 3.28
#   },
#   {
#     "text": "so obviously language models predict the",
#     "start": 346.639,
#     "duration": 4.241
#   },
#   {
#     "text": "next word um gato predicts potentially",
#     "start": 348.24,
#     "duration": 6.0
#   },
#   {
#     "text": "any uh action or any token uh and it's",
#     "start": 350.88,
#     "duration": 4.72
#   },
#   {
#     "text": "just the beginning really it's our most",
#     "start": 354.24,
#     "duration": 3.76
#   },
#   {
#     "text": "general agent one could call it so far",
#     "start": 355.6,
#     "duration": 4.4
#   },
#   {
#     "text": "but um you know that itself can be",
#     "start": 358.0,
#     "duration": 3.6
#   },
#   {
#     "text": "scaled up massively more than we've done",
#     "start": 360.0,
#     "duration": 3.039
#   },
#   {
#     "text": "so far obviously we're in the in the",
#     "start": 361.6,
#     "duration": 4.08
#   },
#   {
#     "text": "middle of doing that but the big part of",
#     "start": 363.039,
#     "duration": 6.081
#   },
#   {
#     "text": "solving agi is creating benchmarks that",
#     "start": 365.68,
#     "duration": 6.48
#   },
#   {
#     "text": "help us get closer and closer sort of",
#     "start": 369.12,
#     "duration": 4.799
#   },
#   {
#     "text": "creating benchmarks that test the",
#     "start": 372.16,
#     "duration": 3.599
#   },
#   {
#     "text": "journalizability and it's just still",
#     "start": 373.919,
#     "duration": 4.881
#   },
#   {
#     "text": "interesting that this fella alan turing",
#     "start": 375.759,
#     "duration": 5.601
#   },
#   {
#     "text": "was one of the first and probably still",
#     "start": 378.8,
#     "duration": 4.959
#   },
#   {
#     "text": "one of the only people that was trying",
#     "start": 381.36,
#     "duration": 4.24
#   },
#   {
#     "text": "maybe philosophically but was trying to",
#     "start": 383.759,
#     "duration": 3.44
#   },
#   {
#     "text": "formulate a benchmark that could be",
#     "start": 385.6,
#     "duration": 3.2
#   },
#   {
#     "text": "followed it is",
#     "start": 387.199,
#     "duration": 4.081
#   },
#   {
#     "text": "even though it's it's fuzzy it's still",
#     "start": 388.8,
#     "duration": 4.08
#   },
#   {
#     "text": "sufficiently rigorous to where you can",
#     "start": 391.28,
#     "duration": 3.84
#   },
#   {
#     "text": "run that test and i still think",
#     "start": 392.88,
#     "duration": 4.159
#   },
#   {
#     "text": "something like the touring test will at",
#     "start": 395.12,
#     "duration": 3.519
#   },
#   {
#     "text": "the end of the day",
#     "start": 397.039,
#     "duration": 3.361
#   },
#   {
#     "text": "be the thing that truly",
#     "start": 398.639,
#     "duration": 3.84
#   },
#   {
#     "text": "impresses other humans",
#     "start": 400.4,
#     "duration": 4.239
#   },
#   {
#     "text": "so that you can have a close friend",
#     "start": 402.479,
#     "duration": 3.921
#   },
#   {
#     "text": "who's an ai system",
#     "start": 404.639,
#     "duration": 3.601
#   },
#   {
#     "text": "for that friend to be a good friend",
#     "start": 406.4,
#     "duration": 4.0
#   },
#   {
#     "text": "they're going to have to be able to",
#     "start": 408.24,
#     "duration": 4.799
#   },
#   {
#     "text": "uh play starcraft",
#     "start": 410.4,
#     "duration": 4.239
#   },
#   {
#     "text": "and they're going to have to do all of",
#     "start": 413.039,
#     "duration": 5.041
#   },
#   {
#     "text": "these tasks um get you a beer so the",
#     "start": 414.639,
#     "duration": 5.28
#   },
#   {
#     "text": "robotics tasks",
#     "start": 418.08,
#     "duration": 5.04
#   },
#   {
#     "text": "uh play games with you use language",
#     "start": 419.919,
#     "duration": 5.84
#   },
#   {
#     "text": "humor all those kinds of things but that",
#     "start": 423.12,
#     "duration": 4.799
#   },
#   {
#     "text": "ultimately can boil down to language it",
#     "start": 425.759,
#     "duration": 4.401
#   },
#   {
#     "text": "feels like not in terms of the ai",
#     "start": 427.919,
#     "duration": 4.56
#   },
#   {
#     "text": "community but in terms of the actual",
#     "start": 430.16,
#     "duration": 4.159
#   },
#   {
#     "text": "impact of general intelligence on the",
#     "start": 432.479,
#     "duration": 3.681
#   },
#   {
#     "text": "world it feels like language will be the",
#     "start": 434.319,
#     "duration": 4.641
#   },
#   {
#     "text": "place where it truly shines i think so",
#     "start": 436.16,
#     "duration": 4.72
#   },
#   {
#     "text": "because it's such an important kind of",
#     "start": 438.96,
#     "duration": 4.079
#   },
#   {
#     "text": "input output for us i think you're right",
#     "start": 440.88,
#     "duration": 4.0
#   },
#   {
#     "text": "i think the turing test that what the",
#     "start": 443.039,
#     "duration": 4.241
#   },
#   {
#     "text": "the kind of the the philosophy behind it",
#     "start": 444.88,
#     "duration": 5.36
#   },
#   {
#     "text": "which is the idea of can can a machine",
#     "start": 447.28,
#     "duration": 7.6
#   },
#   {
#     "text": "mimic the behaviors of a human and men",
#     "start": 450.24,
#     "duration": 6.799
#   },
#   {
#     "text": "and i would say wider than just language",
#     "start": 454.88,
#     "duration": 3.759
#   },
#   {
#     "text": "and text",
#     "start": 457.039,
#     "duration": 3.521
#   },
#   {
#     "text": "then you know in terms of actions and",
#     "start": 458.639,
#     "duration": 3.601
#   },
#   {
#     "text": "everything else creativity all these",
#     "start": 460.56,
#     "duration": 4.079
#   },
#   {
#     "text": "things then um if it can sort of match",
#     "start": 462.24,
#     "duration": 5.04
#   },
#   {
#     "text": "or exceed human cognitive capabilities",
#     "start": 464.639,
#     "duration": 4.481
#   },
#   {
#     "text": "then i think we have a you know true",
#     "start": 467.28,
#     "duration": 3.44
#   },
#   {
#     "text": "intelligence so i thought from that",
#     "start": 469.12,
#     "duration": 3.359
#   },
#   {
#     "text": "perspective you're right i think he did",
#     "start": 470.72,
#     "duration": 5.12
#   },
#   {
#     "text": "formulate the right uh kind of uh setup",
#     "start": 472.479,
#     "duration": 5.361
#   },
#   {
#     "text": "i just i think there'll be a kind of",
#     "start": 475.84,
#     "duration": 3.359
#   },
#   {
#     "text": "humor",
#     "start": 477.84,
#     "duration": 3.28
#   },
#   {
#     "text": "in the ai systems of the future looking",
#     "start": 479.199,
#     "duration": 4.241
#   },
#   {
#     "text": "back to this conversation",
#     "start": 481.12,
#     "duration": 4.88
#   },
#   {
#     "text": "and thinking about the touring test",
#     "start": 483.44,
#     "duration": 5.12
#   },
#   {
#     "text": "and uh also thinking about",
#     "start": 486.0,
#     "duration": 4.319
#   },
#   {
#     "text": "by that time they would know which year",
#     "start": 488.56,
#     "duration": 4.639
#   },
#   {
#     "text": "they were finally able to sort of cross",
#     "start": 490.319,
#     "duration": 4.241
#   },
#   {
#     "text": "the threshold of human level",
#     "start": 493.199,
#     "duration": 3.921
#   },
#   {
#     "text": "intelligence and think",
#     "start": 494.56,
#     "duration": 4.319
#   },
#   {
#     "text": "how funny it is that we humans were",
#     "start": 497.12,
#     "duration": 2.72
#   },
#   {
#     "text": "still",
#     "start": 498.879,
#     "duration": 3.44
#   },
#   {
#     "text": "confused about this whole problem",
#     "start": 499.84,
#     "duration": 4.72
#   },
#   {
#     "text": "that has been long ago been solved",
#     "start": 502.319,
#     "duration": 4.0
#   },
#   {
#     "text": "well hello to the ai agents of the",
#     "start": 504.56,
#     "duration": 4.8
#   },
#   {
#     "text": "future anyway so going back to your",
#     "start": 506.319,
#     "duration": 4.961
#   },
#   {
#     "text": "to your journey when did you fall in",
#     "start": 509.36,
#     "duration": 4.239
#   },
#   {
#     "text": "love with programming first",
#     "start": 511.28,
#     "duration": 4.16
#   },
#   {
#     "text": "well it's pretty uh pretty young age",
#     "start": 513.599,
#     "duration": 3.761
#   },
#   {
#     "text": "actually so um",
#     "start": 515.44,
#     "duration": 4.399
#   },
#   {
#     "text": "you know i started off uh actually games",
#     "start": 517.36,
#     "duration": 4.479
#   },
#   {
#     "text": "was my first love so starting to play",
#     "start": 519.839,
#     "duration": 3.76
#   },
#   {
#     "text": "chess when i was around four years old",
#     "start": 521.839,
#     "duration": 3.761
#   },
#   {
#     "text": "and then um it was actually with",
#     "start": 523.599,
#     "duration": 4.321
#   },
#   {
#     "text": "winnings from a chess competition that i",
#     "start": 525.6,
#     "duration": 4.0
#   },
#   {
#     "text": "managed to buy my first chess computer",
#     "start": 527.92,
#     "duration": 2.88
#   },
#   {
#     "text": "when i was about eight years old it was",
#     "start": 529.6,
#     "duration": 3.44
#   },
#   {
#     "text": "a zx spectrum which was hugely popular",
#     "start": 530.8,
#     "duration": 3.84
#   },
#   {
#     "text": "in the uk at the time",
#     "start": 533.04,
#     "duration": 4.32
#   },
#   {
#     "text": "and uh it's amazing machine because i",
#     "start": 534.64,
#     "duration": 4.639
#   },
#   {
#     "text": "think it trained a whole generation of",
#     "start": 537.36,
#     "duration": 4.08
#   },
#   {
#     "text": "programmers in the uk because it was so",
#     "start": 539.279,
#     "duration": 3.761
#   },
#   {
#     "text": "accessible you know you literally",
#     "start": 541.44,
#     "duration": 3.12
#   },
#   {
#     "text": "switched it on and there was the basic",
#     "start": 543.04,
#     "duration": 4.0
#   },
#   {
#     "text": "prompt and you could just get going and",
#     "start": 544.56,
#     "duration": 4.24
#   },
#   {
#     "text": "um my parents didn't really know",
#     "start": 547.04,
#     "duration": 3.6
#   },
#   {
#     "text": "anything about computers so but because",
#     "start": 548.8,
#     "duration": 3.68
#   },
#   {
#     "text": "it was my money from a chess competition",
#     "start": 550.64,
#     "duration": 4.48
#   },
#   {
#     "text": "i could i could say i i wanted to buy it",
#     "start": 552.48,
#     "duration": 4.479
#   },
#   {
#     "text": "uh and then you know i just went to",
#     "start": 555.12,
#     "duration": 5.04
#   },
#   {
#     "text": "bookstores got books on programming and",
#     "start": 556.959,
#     "duration": 5.601
#   },
#   {
#     "text": "um started typing in you know the",
#     "start": 560.16,
#     "duration": 4.72
#   },
#   {
#     "text": "programming code and and then of course",
#     "start": 562.56,
#     "duration": 4.08
#   },
#   {
#     "text": "um once you start doing that you start",
#     "start": 564.88,
#     "duration": 3.28
#   },
#   {
#     "text": "adjusting it and then making your own",
#     "start": 566.64,
#     "duration": 3.44
#   },
#   {
#     "text": "games and that's when i fell in love",
#     "start": 568.16,
#     "duration": 3.359
#   },
#   {
#     "text": "with computers and realized that they",
#     "start": 570.08,
#     "duration": 5.12
#   },
#   {
#     "text": "were a very magical device um in a way i",
#     "start": 571.519,
#     "duration": 4.88
#   },
#   {
#     "text": "kind of i would have been able to",
#     "start": 575.2,
#     "duration": 2.72
#   },
#   {
#     "text": "explain this at the time but i felt that",
#     "start": 576.399,
#     "duration": 3.041
#   },
#   {
#     "text": "they were sort of almost a magical",
#     "start": 577.92,
#     "duration": 3.76
#   },
#   {
#     "text": "extension of your mind i always had this",
#     "start": 579.44,
#     "duration": 3.76
#   },
#   {
#     "text": "feeling and i've always loved this about",
#     "start": 581.68,
#     "duration": 3.36
#   },
#   {
#     "text": "computers that you can set them off",
#     "start": 583.2,
#     "duration": 4.24
#   },
#   {
#     "text": "doing something some task for you you",
#     "start": 585.04,
#     "duration": 4.32
#   },
#   {
#     "text": "can go to sleep come back the next day",
#     "start": 587.44,
#     "duration": 2.959
#   },
#   {
#     "text": "and it's solved",
#     "start": 589.36,
#     "duration": 3.84
#   },
#   {
#     "text": "um you know that feels magical to me so",
#     "start": 590.399,
#     "duration": 4.401
#   },
#   {
#     "text": "i mean all machines do that to some",
#     "start": 593.2,
#     "duration": 3.68
#   },
#   {
#     "text": "extent they all enhance our natural",
#     "start": 594.8,
#     "duration": 3.84
#   },
#   {
#     "text": "capabilities obviously cars make us",
#     "start": 596.88,
#     "duration": 4.16
#   },
#   {
#     "text": "allow us to move faster than we can run",
#     "start": 598.64,
#     "duration": 4.879
#   },
#   {
#     "text": "but this was a machine to extend the",
#     "start": 601.04,
#     "duration": 3.359
#   },
#   {
#     "text": "mind",
#     "start": 603.519,
#     "duration": 3.601
#   },
#   {
#     "text": "and and then of course ai is the",
#     "start": 604.399,
#     "duration": 4.88
#   },
#   {
#     "text": "ultimate expression of what a machine",
#     "start": 607.12,
#     "duration": 4.959
#   },
#   {
#     "text": "may be able to do or learn so",
#     "start": 609.279,
#     "duration": 4.641
#   },
#   {
#     "text": "very naturally for me that thought",
#     "start": 612.079,
#     "duration": 3.841
#   },
#   {
#     "text": "extended into into ai quite quickly",
#     "start": 613.92,
#     "duration": 4.479
#   },
#   {
#     "text": "remember the the programming language",
#     "start": 615.92,
#     "duration": 3.84
#   },
#   {
#     "text": "that was first",
#     "start": 618.399,
#     "duration": 2.641
#   },
#   {
#     "text": "started",
#     "start": 619.76,
#     "duration": 2.72
#   },
#   {
#     "text": "special to the machine no it was just",
#     "start": 621.04,
#     "duration": 2.96
#   },
#   {
#     "text": "the base it was just i think it was just",
#     "start": 622.48,
#     "duration": 3.599
#   },
#   {
#     "text": "basic uh on the zx spectrum i don't know",
#     "start": 624.0,
#     "duration": 3.92
#   },
#   {
#     "text": "what specific form it was and then later",
#     "start": 626.079,
#     "duration": 5.041
#   },
#   {
#     "text": "on i got a commodore amiga which uh",
#     "start": 627.92,
#     "duration": 5.2
#   },
#   {
#     "text": "was a fantastic machine no you're just",
#     "start": 631.12,
#     "duration": 3.92
#   },
#   {
#     "text": "showing off so yeah well lots of my",
#     "start": 633.12,
#     "duration": 4.0
#   },
#   {
#     "text": "friends had atari st's and i i managed",
#     "start": 635.04,
#     "duration": 3.76
#   },
#   {
#     "text": "to get amigas it was a bit more powerful",
#     "start": 637.12,
#     "duration": 3.839
#   },
#   {
#     "text": "and uh and that was incredible and used",
#     "start": 638.8,
#     "duration": 5.2
#   },
#   {
#     "text": "to do um programming in assembler and",
#     "start": 640.959,
#     "duration": 5.921
#   },
#   {
#     "text": "and uh also amos basic this this",
#     "start": 644.0,
#     "duration": 4.64
#   },
#   {
#     "text": "specific form of basic it was incredible",
#     "start": 646.88,
#     "duration": 4.0
#   },
#   {
#     "text": "actually as well all my coding skills",
#     "start": 648.64,
#     "duration": 4.48
#   },
#   {
#     "text": "and when did you fall in love with ai so",
#     "start": 650.88,
#     "duration": 4.56
#   },
#   {
#     "text": "when did you first",
#     "start": 653.12,
#     "duration": 3.92
#   },
#   {
#     "text": "start to gain an understanding that you",
#     "start": 655.44,
#     "duration": 4.079
#   },
#   {
#     "text": "can not just write programs that",
#     "start": 657.04,
#     "duration": 4.479
#   },
#   {
#     "text": "do some mathematical operations for you",
#     "start": 659.519,
#     "duration": 4.961
#   },
#   {
#     "text": "while you sleep but something that's",
#     "start": 661.519,
#     "duration": 4.88
#   },
#   {
#     "text": "a keen to",
#     "start": 664.48,
#     "duration": 4.24
#   },
#   {
#     "text": "bringing an entity to life",
#     "start": 666.399,
#     "duration": 3.201
#   },
#   {
#     "text": "sort of",
#     "start": 668.72,
#     "duration": 3.04
#   },
#   {
#     "text": "a thing that can figure out something",
#     "start": 669.6,
#     "duration": 4.16
#   },
#   {
#     "text": "more complicated than uh",
#     "start": 671.76,
#     "duration": 4.0
#   },
#   {
#     "text": "than a simple mathematical operation",
#     "start": 673.76,
#     "duration": 3.759
#   },
#   {
#     "text": "yeah so there was a few stages for me",
#     "start": 675.76,
#     "duration": 4.16
#   },
#   {
#     "text": "all while i was very young so first of",
#     "start": 677.519,
#     "duration": 4.241
#   },
#   {
#     "text": "all as i was trying to improve at",
#     "start": 679.92,
#     "duration": 3.44
#   },
#   {
#     "text": "playing chess i was captaining various",
#     "start": 681.76,
#     "duration": 3.199
#   },
#   {
#     "text": "england junior chess teams and at the",
#     "start": 683.36,
#     "duration": 3.28
#   },
#   {
#     "text": "time when i was about you know maybe 10",
#     "start": 684.959,
#     "duration": 3.44
#   },
#   {
#     "text": "11 years old i was gonna become a",
#     "start": 686.64,
#     "duration": 3.12
#   },
#   {
#     "text": "professional chess player that was my",
#     "start": 688.399,
#     "duration": 2.241
#   },
#   {
#     "text": "first",
#     "start": 689.76,
#     "duration": 4.319
#   },
#   {
#     "text": "thought um that dream was there sure she",
#     "start": 690.64,
#     "duration": 5.04
#   },
#   {
#     "text": "tried to get to the highest level yeah",
#     "start": 694.079,
#     "duration": 4.241
#   },
#   {
#     "text": "so i was um you know i got to when i was",
#     "start": 695.68,
#     "duration": 4.32
#   },
#   {
#     "text": "about 12 years old i got to master stand",
#     "start": 698.32,
#     "duration": 3.199
#   },
#   {
#     "text": "and i was second highest rated player in",
#     "start": 700.0,
#     "duration": 3.279
#   },
#   {
#     "text": "the world to judith polgar who obviously",
#     "start": 701.519,
#     "duration": 4.161
#   },
#   {
#     "text": "ended up being an amazing chess player",
#     "start": 703.279,
#     "duration": 6.161
#   },
#   {
#     "text": "and uh world women's champion and when i",
#     "start": 705.68,
#     "duration": 5.2
#   },
#   {
#     "text": "was trying to improve at chess where you",
#     "start": 709.44,
#     "duration": 2.959
#   },
#   {
#     "text": "know what you do is you obviously first",
#     "start": 710.88,
#     "duration": 2.88
#   },
#   {
#     "text": "of all you're trying to improve your own",
#     "start": 712.399,
#     "duration": 4.56
#   },
#   {
#     "text": "thinking processes so that leads you to",
#     "start": 713.76,
#     "duration": 4.72
#   },
#   {
#     "text": "thinking about thinking how is your",
#     "start": 716.959,
#     "duration": 3.601
#   },
#   {
#     "text": "brain coming up with these ideas why is",
#     "start": 718.48,
#     "duration": 4.479
#   },
#   {
#     "text": "it making mistakes how can you how can",
#     "start": 720.56,
#     "duration": 4.16
#   },
#   {
#     "text": "you improve that thought process but the",
#     "start": 722.959,
#     "duration": 3.921
#   },
#   {
#     "text": "second thing is that you it was just the",
#     "start": 724.72,
#     "duration": 4.239
#   },
#   {
#     "text": "beginning this was like in the in the",
#     "start": 726.88,
#     "duration": 4.399
#   },
#   {
#     "text": "early 80s mid 80s of chess computers if",
#     "start": 728.959,
#     "duration": 3.68
#   },
#   {
#     "text": "you remember they were physical boards",
#     "start": 731.279,
#     "duration": 2.881
#   },
#   {
#     "text": "like the one we have in front of us and",
#     "start": 732.639,
#     "duration": 3.361
#   },
#   {
#     "text": "you pressed down the you know the",
#     "start": 734.16,
#     "duration": 4.16
#   },
#   {
#     "text": "squares and i think kasparov had a",
#     "start": 736.0,
#     "duration": 5.279
#   },
#   {
#     "text": "branded version of it that i i i got and",
#     "start": 738.32,
#     "duration": 5.04
#   },
#   {
#     "text": "um you were you know used to they're not",
#     "start": 741.279,
#     "duration": 3.521
#   },
#   {
#     "text": "as strong as they are today but they",
#     "start": 743.36,
#     "duration": 3.2
#   },
#   {
#     "text": "were they were pretty strong and you",
#     "start": 744.8,
#     "duration": 4.4
#   },
#   {
#     "text": "used to practice against them um to try",
#     "start": 746.56,
#     "duration": 4.24
#   },
#   {
#     "text": "and improve your openings and other",
#     "start": 749.2,
#     "duration": 3.199
#   },
#   {
#     "text": "things and so i remember i think i",
#     "start": 750.8,
#     "duration": 2.88
#   },
#   {
#     "text": "probably got my first one i was around",
#     "start": 752.399,
#     "duration": 4.161
#   },
#   {
#     "text": "11 or 12. and i remember thinking um",
#     "start": 753.68,
#     "duration": 4.32
#   },
#   {
#     "text": "this is amazing you know how how has",
#     "start": 756.56,
#     "duration": 4.32
#   },
#   {
#     "text": "someone programmed uh uh this this chess",
#     "start": 758.0,
#     "duration": 5.76
#   },
#   {
#     "text": "board to play chess uh and uh it was",
#     "start": 760.88,
#     "duration": 4.959
#   },
#   {
#     "text": "very formative book i bought which was",
#     "start": 763.76,
#     "duration": 4.079
#   },
#   {
#     "text": "called the chess computer handbook by",
#     "start": 765.839,
#     "duration": 4.481
#   },
#   {
#     "text": "david levy which came out in 1984 or",
#     "start": 767.839,
#     "duration": 3.521
#   },
#   {
#     "text": "something so i must have got it when i",
#     "start": 770.32,
#     "duration": 3.84
#   },
#   {
#     "text": "was about 11 12 and it explained fully",
#     "start": 771.36,
#     "duration": 4.8
#   },
#   {
#     "text": "how these chess programs were made i",
#     "start": 774.16,
#     "duration": 4.72
#   },
#   {
#     "text": "remember my first ai program being uh",
#     "start": 776.16,
#     "duration": 5.119
#   },
#   {
#     "text": "programming my amiga it couldn't it",
#     "start": 778.88,
#     "duration": 4.0
#   },
#   {
#     "text": "wasn't powerful enough to play chess i",
#     "start": 781.279,
#     "duration": 2.961
#   },
#   {
#     "text": "couldn't write a whole chess program but",
#     "start": 782.88,
#     "duration": 3.84
#   },
#   {
#     "text": "i wrote a program for it to play othello",
#     "start": 784.24,
#     "duration": 4.0
#   },
#   {
#     "text": "reversey it's sometimes called i think",
#     "start": 786.72,
#     "duration": 3.919
#   },
#   {
#     "text": "in the u.s and so a slightly simpler",
#     "start": 788.24,
#     "duration": 4.32
#   },
#   {
#     "text": "game than chess but i used all of the",
#     "start": 790.639,
#     "duration": 3.841
#   },
#   {
#     "text": "principles that chess programs had alpha",
#     "start": 792.56,
#     "duration": 3.92
#   },
#   {
#     "text": "beta search all of that and that was my",
#     "start": 794.48,
#     "duration": 3.28
#   },
#   {
#     "text": "first ai program i remember that very",
#     "start": 796.48,
#     "duration": 3.2
#   },
#   {
#     "text": "well was around 12 years old so that",
#     "start": 797.76,
#     "duration": 4.079
#   },
#   {
#     "text": "that that brought me into ai and then",
#     "start": 799.68,
#     "duration": 4.56
#   },
#   {
#     "text": "the second part was later on uh when i",
#     "start": 801.839,
#     "duration": 4.721
#   },
#   {
#     "text": "was around 1617 and i was writing games",
#     "start": 804.24,
#     "duration": 4.48
#   },
#   {
#     "text": "professionally designing games uh",
#     "start": 806.56,
#     "duration": 4.32
#   },
#   {
#     "text": "writing a game called theme park which",
#     "start": 808.72,
#     "duration": 5.2
#   },
#   {
#     "text": "um had ai as a core gameplay component",
#     "start": 810.88,
#     "duration": 5.92
#   },
#   {
#     "text": "as part of the simulation um and it sold",
#     "start": 813.92,
#     "duration": 4.159
#   },
#   {
#     "text": "you know millions of copies around the",
#     "start": 816.8,
#     "duration": 3.44
#   },
#   {
#     "text": "world and people loved the way that the",
#     "start": 818.079,
#     "duration": 4.081
#   },
#   {
#     "text": "ai even though it was relatively simple",
#     "start": 820.24,
#     "duration": 4.8
#   },
#   {
#     "text": "by today's ai standards um was was",
#     "start": 822.16,
#     "duration": 4.479
#   },
#   {
#     "text": "reacting to the way you as the player",
#     "start": 825.04,
#     "duration": 3.76
#   },
#   {
#     "text": "played it so it was called a sandbox",
#     "start": 826.639,
#     "duration": 3.921
#   },
#   {
#     "text": "game so it's one of the first types of",
#     "start": 828.8,
#     "duration": 4.159
#   },
#   {
#     "text": "games like that along with simcity and",
#     "start": 830.56,
#     "duration": 4.0
#   },
#   {
#     "text": "it meant that every game you played was",
#     "start": 832.959,
#     "duration": 2.641
#   },
#   {
#     "text": "unique",
#     "start": 834.56,
#     "duration": 2.8
#   },
#   {
#     "text": "is there something you could say just on",
#     "start": 835.6,
#     "duration": 3.2
#   },
#   {
#     "text": "a small tangent",
#     "start": 837.36,
#     "duration": 2.4
#   },
#   {
#     "text": "about",
#     "start": 838.8,
#     "duration": 5.36
#   },
#   {
#     "text": "really impressive ai from a game design",
#     "start": 839.76,
#     "duration": 6.8
#   },
#   {
#     "text": "human enjoyment perspective",
#     "start": 844.16,
#     "duration": 4.72
#   },
#   {
#     "text": "really impressive ai that you've seen in",
#     "start": 846.56,
#     "duration": 4.48
#   },
#   {
#     "text": "games and maybe what does it take to",
#     "start": 848.88,
#     "duration": 4.319
#   },
#   {
#     "text": "create ai system and how hard of a",
#     "start": 851.04,
#     "duration": 5.039
#   },
#   {
#     "text": "problem is that so a million questions",
#     "start": 853.199,
#     "duration": 5.041
#   },
#   {
#     "text": "just as a brief tangent",
#     "start": 856.079,
#     "duration": 4.161
#   },
#   {
#     "text": "well look i think um",
#     "start": 858.24,
#     "duration": 4.32
#   },
#   {
#     "text": "games uh games have been significant in",
#     "start": 860.24,
#     "duration": 3.92
#   },
#   {
#     "text": "my life for three reasons so first of",
#     "start": 862.56,
#     "duration": 3.519
#   },
#   {
#     "text": "all to to i was playing them and",
#     "start": 864.16,
#     "duration": 3.919
#   },
#   {
#     "text": "training myself on games when i was a",
#     "start": 866.079,
#     "duration": 4.241
#   },
#   {
#     "text": "kid then i went through a phase of",
#     "start": 868.079,
#     "duration": 4.88
#   },
#   {
#     "text": "designing games and writing ai4 games so",
#     "start": 870.32,
#     "duration": 4.959
#   },
#   {
#     "text": "all the games i i professionally wrote",
#     "start": 872.959,
#     "duration": 4.801
#   },
#   {
#     "text": "uh had ai as a core component and that",
#     "start": 875.279,
#     "duration": 5.521
#   },
#   {
#     "text": "was mostly in the in the 90s and the",
#     "start": 877.76,
#     "duration": 4.639
#   },
#   {
#     "text": "reason i was doing that in games",
#     "start": 880.8,
#     "duration": 3.599
#   },
#   {
#     "text": "industry was at the time the games",
#     "start": 882.399,
#     "duration": 3.761
#   },
#   {
#     "text": "industry i think was the cutting edge of",
#     "start": 884.399,
#     "duration": 4.0
#   },
#   {
#     "text": "technology so whether it was graphics",
#     "start": 886.16,
#     "duration": 4.16
#   },
#   {
#     "text": "with people like john carmack and quake",
#     "start": 888.399,
#     "duration": 5.281
#   },
#   {
#     "text": "and those kind of things or ai i think",
#     "start": 890.32,
#     "duration": 5.04
#   },
#   {
#     "text": "actually all the action was going on in",
#     "start": 893.68,
#     "duration": 3.599
#   },
#   {
#     "text": "games and and we've seen we're still",
#     "start": 895.36,
#     "duration": 3.36
#   },
#   {
#     "text": "reaping the benefits of that even with",
#     "start": 897.279,
#     "duration": 3.68
#   },
#   {
#     "text": "things like gpus which you know i find",
#     "start": 898.72,
#     "duration": 3.6
#   },
#   {
#     "text": "ironic was obviously invented for",
#     "start": 900.959,
#     "duration": 2.961
#   },
#   {
#     "text": "graphics computer graphics but then",
#     "start": 902.32,
#     "duration": 3.759
#   },
#   {
#     "text": "turns out to be amazingly useful for ai",
#     "start": 903.92,
#     "duration": 3.68
#   },
#   {
#     "text": "it just turns out everything's a matrix",
#     "start": 906.079,
#     "duration": 3.76
#   },
#   {
#     "text": "multiplication it appears you know in",
#     "start": 907.6,
#     "duration": 3.44
#   },
#   {
#     "text": "the whole world",
#     "start": 909.839,
#     "duration": 4.24
#   },
#   {
#     "text": "so um so i think games at the time had",
#     "start": 911.04,
#     "duration": 5.12
#   },
#   {
#     "text": "the most cutting edge ai and a lot of",
#     "start": 914.079,
#     "duration": 4.721
#   },
#   {
#     "text": "the the games uh uh we you know i was",
#     "start": 916.16,
#     "duration": 4.08
#   },
#   {
#     "text": "involved in writing so there was a game",
#     "start": 918.8,
#     "duration": 2.8
#   },
#   {
#     "text": "called black and white which was one",
#     "start": 920.24,
#     "duration": 2.8
#   },
#   {
#     "text": "game i was involved with in the early",
#     "start": 921.6,
#     "duration": 3.919
#   },
#   {
#     "text": "stages of which i still think is the",
#     "start": 923.04,
#     "duration": 3.76
#   },
#   {
#     "text": "most um",
#     "start": 925.519,
#     "duration": 3.44
#   },
#   {
#     "text": "impressive uh example of reinforcement",
#     "start": 926.8,
#     "duration": 4.24
#   },
#   {
#     "text": "learning in a computer game so in that",
#     "start": 928.959,
#     "duration": 3.921
#   },
#   {
#     "text": "game you know you trained a little pet",
#     "start": 931.04,
#     "duration": 4.159
#   },
#   {
#     "text": "animal uh and",
#     "start": 932.88,
#     "duration": 4.0
#   },
#   {
#     "text": "yeah and it sort of learned from how you",
#     "start": 935.199,
#     "duration": 3.2
#   },
#   {
#     "text": "were treating it so if you treated it",
#     "start": 936.88,
#     "duration": 4.0
#   },
#   {
#     "text": "badly then it became mean yeah and then",
#     "start": 938.399,
#     "duration": 4.401
#   },
#   {
#     "text": "it would be mean to to your villagers",
#     "start": 940.88,
#     "duration": 3.6
#   },
#   {
#     "text": "and your and your population the sort of",
#     "start": 942.8,
#     "duration": 3.2
#   },
#   {
#     "text": "uh the little tribe that you were",
#     "start": 944.48,
#     "duration": 3.52
#   },
#   {
#     "text": "running uh but if you were kind to it",
#     "start": 946.0,
#     "duration": 3.68
#   },
#   {
#     "text": "then it would be kind and people were",
#     "start": 948.0,
#     "duration": 3.759
#   },
#   {
#     "text": "fascinated by how that was and so was i",
#     "start": 949.68,
#     "duration": 3.519
#   },
#   {
#     "text": "to be honest with the way it kind of",
#     "start": 951.759,
#     "duration": 4.08
#   },
#   {
#     "text": "developed and um especially the mapping",
#     "start": 953.199,
#     "duration": 4.961
#   },
#   {
#     "text": "to good and evil yeah it made you made",
#     "start": 955.839,
#     "duration": 5.281
#   },
#   {
#     "text": "you realize made me realize that you can",
#     "start": 958.16,
#     "duration": 4.96
#   },
#   {
#     "text": "sort of in the way in the choices you",
#     "start": 961.12,
#     "duration": 4.0
#   },
#   {
#     "text": "make can define",
#     "start": 963.12,
#     "duration": 3.04
#   },
#   {
#     "text": "uh the",
#     "start": 965.12,
#     "duration": 4.079
#   },
#   {
#     "text": "where you end up and that means",
#     "start": 966.16,
#     "duration": 5.52
#   },
#   {
#     "text": "all of us are capable of the good",
#     "start": 969.199,
#     "duration": 5.281
#   },
#   {
#     "text": "uh evil it all matters in uh the",
#     "start": 971.68,
#     "duration": 4.719
#   },
#   {
#     "text": "different choices along the trajectory",
#     "start": 974.48,
#     "duration": 3.76
#   },
#   {
#     "text": "to those places that you make it's",
#     "start": 976.399,
#     "duration": 3.921
#   },
#   {
#     "text": "fascinating i mean games can do that",
#     "start": 978.24,
#     "duration": 3.68
#   },
#   {
#     "text": "philosophically to you and it's rare it",
#     "start": 980.32,
#     "duration": 3.519
#   },
#   {
#     "text": "seems rare yeah well games are i think a",
#     "start": 981.92,
#     "duration": 4.24
#   },
#   {
#     "text": "unique medium because um you as the",
#     "start": 983.839,
#     "duration": 3.601
#   },
#   {
#     "text": "player you're not just passively",
#     "start": 986.16,
#     "duration": 4.08
#   },
#   {
#     "text": "consuming the the entertainment right",
#     "start": 987.44,
#     "duration": 5.28
#   },
#   {
#     "text": "you're actually actively involved as an",
#     "start": 990.24,
#     "duration": 4.88
#   },
#   {
#     "text": "as a as an agent so i think that's what",
#     "start": 992.72,
#     "duration": 3.84
#   },
#   {
# ...
#     "duration": 5.761
#   },
#   {
#     "text": "a sort of generalist in a way and that's",
#     "start": 7521.76,
#     "duration": 3.359
#   },
#   {
#     "text": "actually what happened with my games",
#     "start": 7524.0,
#     "duration": 4.079
#   },
#   {
#     "text": "career after chess i i i one of the",
#     "start": 7525.119,
#     "duration": 4.241
#   },
#   {
#     "text": "reasons i stopped playing chess was that",
#     "start": 7528.079,
#     "duration": 2.961
#   },
#   {
#     "text": "i got into computers but also i started",
#     "start": 7529.36,
#     "duration": 3.12
#   },
#   {
#     "text": "realizing there were many other great",
#     "start": 7531.04,
#     "duration": 3.44
#   },
#   {
#     "text": "games out there to play too so",
#     "start": 7532.48,
#     "duration": 3.36
#   },
#   {
#     "text": "i've always been that way inclined",
#     "start": 7534.48,
#     "duration": 3.04
#   },
#   {
#     "text": "multidisciplinary and there's too many",
#     "start": 7535.84,
#     "duration": 3.279
#   },
#   {
#     "text": "interesting things in in the world to",
#     "start": 7537.52,
#     "duration": 4.079
#   },
#   {
#     "text": "spend all your time just on one thing",
#     "start": 7539.119,
#     "duration": 4.641
#   },
#   {
#     "text": "so you mentioned spinoza gotta ask the",
#     "start": 7541.599,
#     "duration": 3.201
#   },
#   {
#     "text": "big",
#     "start": 7543.76,
#     "duration": 3.76
#   },
#   {
#     "text": "ridiculously big question about life",
#     "start": 7544.8,
#     "duration": 4.16
#   },
#   {
#     "text": "what do you think is the meaning of this",
#     "start": 7547.52,
#     "duration": 2.559
#   },
#   {
#     "text": "whole thing",
#     "start": 7548.96,
#     "duration": 4.08
#   },
#   {
#     "text": "uh why are we humans here you've already",
#     "start": 7550.079,
#     "duration": 4.961
#   },
#   {
#     "text": "mentioned that perhaps the universe",
#     "start": 7553.04,
#     "duration": 3.52
#   },
#   {
#     "text": "created us",
#     "start": 7555.04,
#     "duration": 3.52
#   },
#   {
#     "text": "is that why you think we're here",
#     "start": 7556.56,
#     "duration": 3.84
#   },
#   {
#     "text": "to understand how the universe yeah i",
#     "start": 7558.56,
#     "duration": 3.599
#   },
#   {
#     "text": "think my answer to that would be and at",
#     "start": 7560.4,
#     "duration": 4.08
#   },
#   {
#     "text": "least the the life i'm living is to gain",
#     "start": 7562.159,
#     "duration": 5.04
#   },
#   {
#     "text": "and uh to gain and understand the",
#     "start": 7564.48,
#     "duration": 4.719
#   },
#   {
#     "text": "knowledge you know to gain knowledge and",
#     "start": 7567.199,
#     "duration": 3.841
#   },
#   {
#     "text": "understand the universe that's what i",
#     "start": 7569.199,
#     "duration": 4.161
#   },
#   {
#     "text": "think uh i can't see any higher purpose",
#     "start": 7571.04,
#     "duration": 3.52
#   },
#   {
#     "text": "than that if you think back to the",
#     "start": 7573.36,
#     "duration": 2.879
#   },
#   {
#     "text": "classical greeks you know the virtue of",
#     "start": 7574.56,
#     "duration": 3.84
#   },
#   {
#     "text": "gaining knowledge it's uh i think it's",
#     "start": 7576.239,
#     "duration": 4.241
#   },
#   {
#     "text": "that it's one of the few true virtues is",
#     "start": 7578.4,
#     "duration": 5.12
#   },
#   {
#     "text": "to understand um the world around us and",
#     "start": 7580.48,
#     "duration": 6.159
#   },
#   {
#     "text": "the context and humanity better and um",
#     "start": 7583.52,
#     "duration": 4.639
#   },
#   {
#     "text": "and i think if you do that you become",
#     "start": 7586.639,
#     "duration": 3.201
#   },
#   {
#     "text": "more compassionate and more",
#     "start": 7588.159,
#     "duration": 3.361
#   },
#   {
#     "text": "understanding yourself and and more",
#     "start": 7589.84,
#     "duration": 3.2
#   },
#   {
#     "text": "tolerant and all these i think all these",
#     "start": 7591.52,
#     "duration": 3.36
#   },
#   {
#     "text": "other things may flow from that and to",
#     "start": 7593.04,
#     "duration": 2.639
#   },
#   {
#     "text": "me",
#     "start": 7594.88,
#     "duration": 2.16
#   },
#   {
#     "text": "you know understanding the nature of",
#     "start": 7595.679,
#     "duration": 2.96
#   },
#   {
#     "text": "reality that is the biggest question",
#     "start": 7597.04,
#     "duration": 3.199
#   },
#   {
#     "text": "what is going on here is sometimes the",
#     "start": 7598.639,
#     "duration": 3.281
#   },
#   {
#     "text": "colloquial way i say what is really",
#     "start": 7600.239,
#     "duration": 2.96
#   },
#   {
#     "text": "going on here",
#     "start": 7601.92,
#     "duration": 3.52
#   },
#   {
#     "text": "uh it's so mysterious i feel like we're",
#     "start": 7603.199,
#     "duration": 5.201
#   },
#   {
#     "text": "in some huge puzzle and and it's but the",
#     "start": 7605.44,
#     "duration": 5.36
#   },
#   {
#     "text": "world is also seems to be the universe",
#     "start": 7608.4,
#     "duration": 4.56
#   },
#   {
#     "text": "seems to be structured in a way you know",
#     "start": 7610.8,
#     "duration": 3.52
#   },
#   {
#     "text": "why is it structured in a way that",
#     "start": 7612.96,
#     "duration": 3.279
#   },
#   {
#     "text": "science is even possible that you know",
#     "start": 7614.32,
#     "duration": 3.68
#   },
#   {
#     "text": "methods the scientific method works",
#     "start": 7616.239,
#     "duration": 3.201
#   },
#   {
#     "text": "things are repeatable",
#     "start": 7618.0,
#     "duration": 3.92
#   },
#   {
#     "text": "um it feels like it's almost structured",
#     "start": 7619.44,
#     "duration": 4.639
#   },
#   {
#     "text": "in a way to be conducive to gaining",
#     "start": 7621.92,
#     "duration": 4.48
#   },
#   {
#     "text": "knowledge so i feel like and you know",
#     "start": 7624.079,
#     "duration": 3.761
#   },
#   {
#     "text": "why should computers be even possible",
#     "start": 7626.4,
#     "duration": 4.239
#   },
#   {
#     "text": "isn't that amazing that uh computational",
#     "start": 7627.84,
#     "duration": 5.279
#   },
#   {
#     "text": "electronic devices can can can can be",
#     "start": 7630.639,
#     "duration": 4.56
#   },
#   {
#     "text": "possible and they're made of sand our",
#     "start": 7633.119,
#     "duration": 3.761
#   },
#   {
#     "text": "most you know common element that we",
#     "start": 7635.199,
#     "duration": 3.601
#   },
#   {
#     "text": "have you know silicon that on the on the",
#     "start": 7636.88,
#     "duration": 3.52
#   },
#   {
#     "text": "earth's crust they could be made of",
#     "start": 7638.8,
#     "duration": 2.879
#   },
#   {
#     "text": "diamond or something then we would have",
#     "start": 7640.4,
#     "duration": 3.839
#   },
#   {
#     "text": "only had one computer yeah right so it's",
#     "start": 7641.679,
#     "duration": 3.841
#   },
#   {
#     "text": "a lot of things are kind of slightly",
#     "start": 7644.239,
#     "duration": 3.36
#   },
#   {
#     "text": "suspicious to me it sure as heck sounds",
#     "start": 7645.52,
#     "duration": 4.0
#   },
#   {
#     "text": "this puzzle sure sounds like something",
#     "start": 7647.599,
#     "duration": 4.0
#   },
#   {
#     "text": "we talked about earlier what it takes to",
#     "start": 7649.52,
#     "duration": 4.24
#   },
#   {
#     "text": "to design a game",
#     "start": 7651.599,
#     "duration": 3.921
#   },
#   {
#     "text": "that's really fun to play for prolonged",
#     "start": 7653.76,
#     "duration": 3.839
#   },
#   {
#     "text": "periods of time",
#     "start": 7655.52,
#     "duration": 4.0
#   },
#   {
#     "text": "and it does seem like this puzzle like",
#     "start": 7657.599,
#     "duration": 4.08
#   },
#   {
#     "text": "you mentioned the more you learn about",
#     "start": 7659.52,
#     "duration": 4.32
#   },
#   {
#     "text": "it the more you realize how little you",
#     "start": 7661.679,
#     "duration": 3.121
#   },
#   {
#     "text": "know",
#     "start": 7663.84,
#     "duration": 3.2
#   },
#   {
#     "text": "so it humbles you but excites you by the",
#     "start": 7664.8,
#     "duration": 4.64
#   },
#   {
#     "text": "possibility of learning more it's one",
#     "start": 7667.04,
#     "duration": 4.8
#   },
#   {
#     "text": "heck of a one heck of a puzzle we got",
#     "start": 7669.44,
#     "duration": 5.52
#   },
#   {
#     "text": "going on here um so like i mentioned of",
#     "start": 7671.84,
#     "duration": 5.2
#   },
#   {
#     "text": "all the people in the world you're very",
#     "start": 7674.96,
#     "duration": 5.6
#   },
#   {
#     "text": "likely to be the one who creates the agi",
#     "start": 7677.04,
#     "duration": 4.88
#   },
#   {
#     "text": "system",
#     "start": 7680.56,
#     "duration": 3.679
#   },
#   {
#     "text": "um that achieves human level",
#     "start": 7681.92,
#     "duration": 4.48
#   },
#   {
#     "text": "intelligence and goes beyond it so if",
#     "start": 7684.239,
#     "duration": 4.4
#   },
#   {
#     "text": "you got a chance and very well you could",
#     "start": 7686.4,
#     "duration": 3.759
#   },
#   {
#     "text": "be the person that goes into the room",
#     "start": 7688.639,
#     "duration": 4.321
#   },
#   {
#     "text": "with the system and have a conversation",
#     "start": 7690.159,
#     "duration": 5.04
#   },
#   {
#     "text": "maybe you only get to ask one question",
#     "start": 7692.96,
#     "duration": 3.52
#   },
#   {
#     "text": "if you do",
#     "start": 7695.199,
#     "duration": 4.081
#   },
#   {
#     "text": "what question would you ask her",
#     "start": 7696.48,
#     "duration": 5.599
#   },
#   {
#     "text": "i would probably ask um what is the true",
#     "start": 7699.28,
#     "duration": 4.24
#   },
#   {
#     "text": "nature of reality",
#     "start": 7702.079,
#     "duration": 2.56
#   },
#   {
#     "text": "i think that's the question i don't know",
#     "start": 7703.52,
#     "duration": 2.48
#   },
#   {
#     "text": "if i'd understand the answer because",
#     "start": 7704.639,
#     "duration": 3.121
#   },
#   {
#     "text": "maybe it would be 42 or something like",
#     "start": 7706.0,
#     "duration": 4.48
#   },
#   {
#     "text": "that but um that's the question i would",
#     "start": 7707.76,
#     "duration": 4.56
#   },
#   {
#     "text": "ask",
#     "start": 7710.48,
#     "duration": 3.599
#   },
#   {
#     "text": "and then there'll be a deep sigh from",
#     "start": 7712.32,
#     "duration": 3.2
#   },
#   {
#     "text": "the systems like all right how do i",
#     "start": 7714.079,
#     "duration": 3.361
#   },
#   {
#     "text": "explain to the excuse me exactly all",
#     "start": 7715.52,
#     "duration": 4.88
#   },
#   {
#     "text": "right let me i don't have time",
#     "start": 7717.44,
#     "duration": 5.199
#   },
#   {
#     "text": "to explain uh maybe i'll draw you a",
#     "start": 7720.4,
#     "duration": 4.16
#   },
#   {
#     "text": "picture that it is",
#     "start": 7722.639,
#     "duration": 4.48
#   },
#   {
#     "text": "i mean how do you even begin",
#     "start": 7724.56,
#     "duration": 3.679
#   },
#   {
#     "text": "um",
#     "start": 7727.119,
#     "duration": 4.0
#   },
#   {
#     "text": "to answer that question",
#     "start": 7728.239,
#     "duration": 4.88
#   },
#   {
#     "text": "well i think it would um what would you",
#     "start": 7731.119,
#     "duration": 3.201
#   },
#   {
#     "text": "what would you think the answer could",
#     "start": 7733.119,
#     "duration": 3.6
#   },
#   {
#     "text": "possibly look like i think it could it",
#     "start": 7734.32,
#     "duration": 4.24
#   },
#   {
#     "text": "could start looking like",
#     "start": 7736.719,
#     "duration": 2.641
#   },
#   {
#     "text": "uh",
#     "start": 7738.56,
#     "duration": 2.96
#   },
#   {
#     "text": "uh more fundamental explanations of",
#     "start": 7739.36,
#     "duration": 4.48
#   },
#   {
#     "text": "physics would be the beginning you know",
#     "start": 7741.52,
#     "duration": 4.159
#   },
#   {
#     "text": "more careful specification of that",
#     "start": 7743.84,
#     "duration": 3.44
#   },
#   {
#     "text": "taking you walking us through by the",
#     "start": 7745.679,
#     "duration": 3.761
#   },
#   {
#     "text": "hand as to what one would do to maybe",
#     "start": 7747.28,
#     "duration": 4.08
#   },
#   {
#     "text": "prove those things out maybe giving you",
#     "start": 7749.44,
#     "duration": 3.6
#   },
#   {
#     "text": "glimpses of",
#     "start": 7751.36,
#     "duration": 3.44
#   },
#   {
#     "text": "what things you totally missed in the",
#     "start": 7753.04,
#     "duration": 3.119
#   },
#   {
#     "text": "physics of today",
#     "start": 7754.8,
#     "duration": 4.319
#   },
#   {
#     "text": "exactly just here here's glimpses of no",
#     "start": 7756.159,
#     "duration": 4.801
#   },
#   {
#     "text": "like there's a much",
#     "start": 7759.119,
#     "duration": 2.96
#   },
#   {
#     "text": "uh",
#     "start": 7760.96,
#     "duration": 2.96
#   },
#   {
#     "text": "a much more elaborate world or a much",
#     "start": 7762.079,
#     "duration": 4.56
#   },
#   {
#     "text": "simpler world or something",
#     "start": 7763.92,
#     "duration": 5.199
#   },
#   {
#     "text": "a much deeper maybe simpler explanation",
#     "start": 7766.639,
#     "duration": 4.401
#   },
#   {
#     "text": "yes of things right than the standard",
#     "start": 7769.119,
#     "duration": 3.6
#   },
#   {
#     "text": "model of physics which we know doesn't",
#     "start": 7771.04,
#     "duration": 5.119
#   },
#   {
#     "text": "work but we still keep adding to so um",
#     "start": 7772.719,
#     "duration": 5.041
#   },
#   {
#     "text": "and and that's how i think the beginning",
#     "start": 7776.159,
#     "duration": 2.881
#   },
#   {
#     "text": "of an explanation would look and it",
#     "start": 7777.76,
#     "duration": 2.879
#   },
#   {
#     "text": "would start encompassing many of the",
#     "start": 7779.04,
#     "duration": 3.199
#   },
#   {
#     "text": "mysteries that we have wondered about",
#     "start": 7780.639,
#     "duration": 3.6
#   },
#   {
#     "text": "for thousands of years like you know",
#     "start": 7782.239,
#     "duration": 3.521
#   },
#   {
#     "text": "consciousness",
#     "start": 7784.239,
#     "duration": 4.48
#   },
#   {
#     "text": "uh life and gravity all of these things",
#     "start": 7785.76,
#     "duration": 4.56
#   },
#   {
#     "text": "yeah giving us a glimpses of",
#     "start": 7788.719,
#     "duration": 3.761
#   },
#   {
#     "text": "explanations for those things yeah",
#     "start": 7790.32,
#     "duration": 3.6
#   },
#   {
#     "text": "well um",
#     "start": 7792.48,
#     "duration": 3.92
#   },
#   {
#     "text": "damas dear one of the special",
#     "start": 7793.92,
#     "duration": 4.319
#   },
#   {
#     "text": "human beings in this giant puzzle of",
#     "start": 7796.4,
#     "duration": 3.759
#   },
#   {
#     "text": "ours and it's a huge honor that you",
#     "start": 7798.239,
#     "duration": 3.201
#   },
#   {
#     "text": "would take a pause from the bigger",
#     "start": 7800.159,
#     "duration": 3.121
#   },
#   {
#     "text": "puzzle to solve this small puzzle of a",
#     "start": 7801.44,
#     "duration": 3.84
#   },
#   {
#     "text": "conversation with me today it's truly an",
#     "start": 7803.28,
#     "duration": 3.359
#   },
#   {
#     "text": "honor and a pleasure thank you thank you",
#     "start": 7805.28,
#     "duration": 3.68
#   },
#   {
#     "text": "i really enjoyed it thanks lex",
#     "start": 7806.639,
#     "duration": 3.281
#   },
#   {
#     "text": "thanks for listening to this",
#     "start": 7808.96,
#     "duration": 2.96
#   },
#   {
#     "text": "conversation with demas establish to",
#     "start": 7809.92,
#     "duration": 3.6
#   },
#   {
#     "text": "support this podcast please check out",
#     "start": 7811.92,
#     "duration": 3.759
#   },
#   {
#     "text": "our sponsors in the description",
#     "start": 7813.52,
#     "duration": 4.24
#   },
#   {
#     "text": "and now let me leave you with some words",
#     "start": 7815.679,
#     "duration": 4.56
#   },
#   {
#     "text": "from edskar dykstra",
#     "start": 7817.76,
#     "duration": 4.319
#   },
#   {
#     "text": "computer science is no more about",
#     "start": 7820.239,
#     "duration": 3.041
#   },
#   {
#     "text": "computers",
#     "start": 7822.079,
#     "duration": 4.961
#   },
#   {
#     "text": "than astronomy is about telescopes",
#     "start": 7823.28,
#     "duration": 5.52
#   },
#   {
#     "text": "thank you for listening and hope to see",
#     "start": 7827.04,
#     "duration": 5.32
#   },
#   {
#     "text": "you next time",
#     "start": 7828.8,
#     "duration": 3.56
#   }
# ]

# %% [markdown]
# # 1.**Indexing** (Text Splitting)

# %%
from youtube_transcript_api import YouTubeTranscriptApi, TranscriptsDisabled
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import FAISS
from langchain_core.prompts import PromptTemplate

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

# Extract just the text from your transcript
splitter = RecursiveCharacterTextSplitter(
    chunk_size=1500,  # Focused paragraphs
    chunk_overlap=600,  # Preserves context
    separators=["\n\n", "\n", ". ", "? ", "! "]  # Split at natural boundaries
)

chunks = splitter.create_documents(texts)

# %%
len(chunks)
# Out:
# 3790

# %%
chunks[0]
# Out:
# Document(metadata={}, page_content='the following is a conversation with')

# %% [markdown]
# # **1.Indexing (Embedding Generation and storing in vector store)**

# %%
from langchain_community.embeddings import HuggingFaceEmbeddings

# Lightweight model (good for CPU)
embeddings = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")

# Higher quality (requires more RAM)
# embeddings = HuggingFaceEmbeddings(model_name="all-mpnet-base-v2")

vector_store=FAISS.from_documents(chunks,embedding=embeddings)
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `BertSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)

# %%
vector_store.index_to_docstore_id
# Out:
# {0: '37e00221-24c8-48dd-bda0-e5fb03b95e95',
#  1: 'bb1d7ee2-8611-4f27-aefd-6ef62b1c0924',
#  2: '2d27cfd7-61e6-489b-9540-6c387d6c5da7',
#  3: '06312a1e-f614-4e88-8747-a6bc302b797a',
#  4: '1962371e-a11a-4d3e-afc8-920b1a80b261',
#  5: '6e3c35a7-5285-4b93-91e3-3050feb37288',
#  6: '596c9027-0f8b-4ae2-bffc-23051c278edf',
#  7: 'd1b6e891-3805-485c-8e28-1b2fb98992f2',
#  8: 'ba37f72a-63ea-4b62-af10-b8ade9c9859f',
#  9: '494ed4bf-6cf8-48f7-b246-647a6e765a2d',
#  10: '3c16a8e2-34d5-4793-81d0-9e2710969b0d',
#  11: '1cf956ee-408d-4280-b23e-1385140e6689',
#  12: 'eb05ff4c-ae74-4f34-be07-af8d457df32d',
#  13: '0b43ed7c-f86b-4da5-a3a4-4d090637e95d',
#  14: '3a58c044-a58c-46ff-9076-a9dea08ba82e',
#  15: 'e8bc3a13-dc8b-408f-9673-64aecab51512',
#  16: 'e7d0a6c6-3a07-411b-81f7-6bae006ef688',
#  17: 'a811551a-8a95-4e7e-ada4-686b0107dbf7',
#  18: '1994c6ec-a191-4c7f-9b1f-608192cfcb22',
#  19: '564c04bc-8abd-4136-817a-0248cf82e013',
#  20: '06e48ba9-28a2-42e0-bf71-fce1370957bd',
#  21: '663febcb-e1b1-46a8-b7d9-c2c3b7172295',
#  22: 'f68ff539-8f37-43fe-a7e9-3743569e9494',
#  23: '02e63647-4adb-431f-b997-b346a48be190',
#  24: 'da88a1b6-2b4c-43dd-b391-b7e100e821b7',
#  25: 'b3c7fdda-d846-4e3f-947e-5e8ef32299dd',
#  26: 'c4a12ee3-8f58-4739-8ee0-a26718d2a104',
#  27: 'e704de84-a9f0-4f06-808f-a28d8cb26533',
#  28: '675f9382-5c26-415a-8a76-1b2782a0f5b1',
#  29: 'd925b8f0-76da-45ce-8fde-bde47604cc1e',
#  30: '94b77383-bd4d-4169-a66d-8281c39ab6f8',
#  31: 'd65c89ce-bb09-47c3-900c-bbbade2e261a',
#  169: 'f7aff0a8-94d7-4727-8794-bda41c998312',
#  170: 'fa40e7f4-9cac-4f09-886b-b67a3450f20f',
#  171: '7ffeff22-0a6a-4b21-b9b8-a18f7de13dd2',
#  172: '2c1ef8c3-45f7-48be-b76f-18eede23e648',
#  173: '992da5f3-677f-41d7-b83f-32a03c8b918d',
#  174: '39ce3628-a10d-4543-87ff-ea34416598ac',
#  175: 'f05ec52f-e238-4242-96ef-30c0c186be83',
#  176: 'cbbca2ee-5d90-4b1a-9032-633ad24eb4d6',
#  177: 'c09eafcb-45a1-4124-a315-c68c193f1167',
#  178: '2ed637eb-95ca-454b-bed9-1942d8fdaaf4',
#  179: '71fe56cf-2efa-441f-ae28-78859b2e4d7b',
#  180: '62de749b-8ed7-441b-b91b-cc49eff50a3c',
#  181: '4c98017c-daf2-456a-ad2e-0f54ec850550',
#  182: '93834a5f-8760-4db1-ace0-9b70a0337198',
#  183: '14282dd6-886e-4785-b2e0-295fcc05e424',
#  184: 'ec0cf45f-ba5b-4c12-bff3-a1b3e4f16652',
#  185: '8f785380-9ae1-4347-87c6-be65eba785be',
#  186: 'a48fa879-5adb-4f29-94b6-412ce22921cb',
#  187: 'bd1982bb-7c30-45de-a448-b4efc0694aa3',
#  188: 'd4079c0f-d721-4ade-9743-269bc6180cf2',
#  189: 'b9109d40-dc46-449c-baee-5efa02775497',
#  190: '4062a433-8e4a-46b4-ad7e-ae05bb89fcfc',
#  191: '85126af7-9782-4bab-a8b4-6220b86916a3',
#  192: 'caaeb208-f785-4113-95e1-0de062c4e83b',
#  193: '65e6be37-3f13-4751-9a5e-017114e29296',
#  194: 'e77b745f-b6a6-4cea-a8eb-e50313da781f',
#  195: '31caeb23-20d5-453d-ad84-abbf2b6458bc',
#  196: '4137a7c5-d509-4dd9-9783-0642eb98ea97',
#  197: 'b41225e4-8da9-4dc7-84b8-fe8a37a513d1',
#  198: 'd273e2cb-f904-46fe-ab99-616b08a01734',
#  199: '5b757c49-52f8-44b3-9bab-c10e8545e935',
#  200: '71ade967-e97f-49ea-83c0-5cc16094a1bc',
#  201: 'a10da4fa-ed58-4164-b74a-4b5a2081bc6b',
#  202: '56bc2942-4987-4a8e-b43a-a30e76819707',
#  203: '824b384f-708f-44c1-a3aa-c06fe2dfd02c',
#  204: '6b4c3cdb-e87c-4c23-ac5b-2fccc3ed94a7',
#  205: '0df664b0-7e09-4b0e-b232-d84cae114e54',
#  206: '29bfa9a9-c3ce-4aff-a4ee-bf62dc12902e',
#  207: '45d96545-0a1e-42fb-8ded-cfd9be636a78',
#  208: 'd8e32b86-ff61-4321-b9be-38bf4dccea12',
#  209: 'c80e2a52-52a4-49df-9c4e-9d06bcf0e00b',
#  210: 'e56b845a-f2a7-4c07-a0b3-727c9361f75b',
#  211: '29dd9f39-9a8e-4e79-992c-89f7d409437c',
#  212: 'a7bb5ac1-fbd8-4cd5-9bbf-323f042ecdca',
#  213: '30d27df0-8a3b-4595-81d6-820e0fe7a879',
#  670: '1a49e1ef-3ffe-4e2a-a66a-58701790b233',
#  671: '31b1e3fe-de93-421b-9c6e-05377745d452',
#  672: '2385f909-d765-42cb-8646-31201e95ef14',
#  673: '30a1943c-5f21-4e34-9e62-2eb6ec88068b',
#  674: '4f866572-5d86-4b0d-8204-074ddbf228ef',
#  675: 'acdcc202-2170-4683-9851-56526961b892',
#  676: '6134e80b-bf4a-42b7-8b63-31bbb039885f',
#  677: '395b097d-d19a-426c-87b0-49b690fee31e',
#  678: '7f5da2b6-27db-4801-88c7-a757c176402a',
#  679: 'a55a403b-4fa4-4613-938b-4301a64ccb57',
#  680: '56a7f24d-1767-4150-9ffb-5980ccb2c9c5',
#  681: 'd87fca7b-a452-46cd-a912-2d3859bc91e2',
#  682: '1fb78eca-b4c0-4751-b8e0-429b98f7d6ab',
#  683: '2a7f5db8-a124-4f6c-ac90-5c4e189e4dd2',
#  684: '34f81569-4f56-40ba-8a5f-2b0d2ca16845',
#  685: '2c593a7b-4c88-49c6-870d-b7d9aefe4d6f',
#  686: 'c6292681-1d90-4a65-aba7-9b7048be5931',
#  687: 'cecf5ef7-44b3-4fd4-b9be-9b2f5778bf3b',
#  688: '151daf03-8638-4a57-b92c-2b04ffa6bb64',
#  689: '8f7ee5ba-4a39-4e04-aa01-f56531a97b50',
#  690: '126515d8-a1df-41b1-877a-256c8b328b78',
#  691: '5865f484-d7fc-4c4b-a3b8-d6e76948d7ef',
#  692: 'e7facc10-2526-40a2-afec-4100252798e2',
#  693: '238a47a9-57bd-4cfe-93c9-5ee69ebd78b0',
#  694: '08a01acd-efa0-4771-962d-3886c31d1486',
#  695: 'a41827d3-ae95-4d1d-91a6-e5eada76acee',
#  696: 'fa522aa9-fd3a-4b1f-bd71-293eeecb3084',
#  697: '38ac055c-f06f-447f-84e8-47b85b521663',
#  698: '9ddae685-5b8b-4459-8738-3eb76cff2af2',
#  699: 'ba8df739-3376-4be5-b5a9-2c27a32162c9',
#  700: '1082d2e1-39e9-44d1-9417-b1857d812747',
#  701: 'efea718b-8ce4-48b0-99be-058b42fa9326',
#  702: '78f353d5-42d2-450f-9c27-e6ae927857e0',
#  703: 'c80a5070-80dd-42cd-90c5-43322a361f86',
#  704: '84098930-f952-4d0a-ab12-d8fc96453e75',
#  705: 'd6fee06d-f8e1-4f15-911b-317617b8096d',
#  706: 'e90a49d3-4d0e-4c26-b4df-a1e362f7f37d',
#  707: 'e507e952-b8bc-4554-a75d-84cbc6b23915',
#  708: 'e3f40814-56cd-455e-8134-589aea212786',
#  709: '4b69dbf3-c415-4782-93d1-455f3e71e48c',
#  710: '622f2506-6bda-4791-9041-836b7212a3fe',
#  711: 'a9aec179-5f1a-4f35-95e4-2e55bcd150a9',
#  712: 'ecb927ca-5f4c-4725-a494-b52fdfa4a33b',
#  713: '14161490-5435-4830-9c58-c6082c24481d',
#  714: '85ec800b-0550-460b-b1f0-a058343d65a1',
#  715: '01f75bff-d3ae-41f5-887f-03e139fadaa3',
#  716: '3f34dbd5-b610-430d-bd01-8c6d9b071a1d',
#  807: '35c2a09f-e1c2-46b4-9091-1c807420f36e',
#  808: '0badf44c-ce4c-4337-a820-2cdb0fe466a2',
#  809: '81c11fd5-cd32-43be-9821-c498be358466',
#  810: '04e15b86-89ef-4c1f-8201-939be3f0244a',
#  811: 'c0bcc5a6-c28a-4632-bd50-6246f756f7ef',
#  812: '65344360-6f21-4f71-b237-d5a9204148ed',
#  813: 'e3cd22a3-b4e1-4382-828b-af2119a21f9a',
#  814: '3a0409d0-5d02-4826-9d00-5e509980bc52',
#  815: '3eaabd0f-508e-4e15-afb4-a91a690fd7de',
#  816: '1fbe9a14-64e8-4964-9876-f51bd98fe2da',
#  817: '9d678d05-89aa-4512-9484-2f2f336cba62',
#  818: '1c6a5c40-4237-4d62-bec7-3f8c015892f9',
#  819: 'ceba0fe8-bb18-4685-b681-6a4c6c07b8c9',
#  820: 'f82b0a8c-a789-47aa-90bc-fec5b7a4e019',
#  821: 'dd66c5ff-e33b-436f-b0c2-e52d17337137',
#  822: 'af290d5c-a439-46be-b7ac-891c2f9b95d7',
#  823: 'd305d27c-1553-412e-b609-c3599890f955',
#  824: '2f831c61-6c0f-4616-bcca-5f4ef0ce3cbd',
#  825: '30586c6f-6873-473a-9930-6e9f27311b4c',
#  826: 'bb6990b4-0b03-4c3f-8395-b1ed58253f8b',
#  827: 'c3fb77b4-8f48-46ee-bb20-2d42544fa7d4',
#  828: '98dcf77b-7af8-4ded-9a37-2d8576bf0b2d',
#  829: 'ceea3de1-c504-4fe3-8c52-b2312b7459bd',
#  830: 'c70fc2f2-e1d6-4c15-a721-98098f5a5b69',
#  831: '5257164c-a769-4381-b1a0-6367f71fab8d',
#  832: '03e4659d-fa17-4be2-b79d-21078eace229',
#  833: '99eacc14-ab0e-40b6-b7ac-3641bf1b6c37',
#  834: 'a0eb9b13-8f22-464f-8bde-1ede07c7fb06',
#  835: '7c1269b2-2e2a-4663-a0fd-3cf6c4493f12',
#  836: '002a6240-5e6f-44e2-865e-1491b7d4a90f',
#  837: '68c52c1b-78d5-407c-af9b-db7643771008',
#  838: 'c05a228d-59c7-4bc6-9906-1d4abb1e7656',
#  839: '3377e216-7479-4f72-8f0b-afc2600f00a2',
#  840: '1662f9e9-a97d-4d56-bd25-82b24020881c',
#  841: '4937854d-dffb-4189-82b8-3aecaa632e8b',
#  842: 'f4276a17-eb0e-4cf3-9f47-0901a582bd75',
#  843: 'a3cfc53e-f354-42c5-bba7-266bd1ab3d8a',
#  844: 'c23348d9-15a9-4c4f-b031-90c0b35d344d',
#  845: '86f07eeb-8c41-4bec-8f2d-4200c6b3c35c',
#  846: 'c0fd66ff-80fc-4fa7-8ea8-92ebbf4fe4bd',
#  847: '4ef36964-6d58-4f54-8a38-1f8d3a1fb9fb',
#  848: '36e3a22d-9f4f-4638-ae66-f1b5186ac109',
#  849: 'babc5b91-1d2f-4f1f-bee0-8f8e63173c84',
#  850: 'd4d0a621-b4f7-4908-8ec0-a0aeaeafdf31',
#  851: '1b830bfd-6c8e-4cb0-af7f-9a69ddf81b3a',
#  852: '296aa216-af0b-4bdd-b9b4-23d1803f50a4',
#  853: 'b67dcd4e-649e-4be7-af97-5bf17ffb837b',
#  854: 'c49b2648-fb5c-48d0-b288-946a0aa1bae2',
#  855: '615d2382-1f25-44bd-84ca-ac7088e9736b',
#  856: '1d7206ba-da8a-4b49-a2cb-a3840ac3f07f',
#  857: 'ded612d6-94ec-442d-9d4a-ed516a1e2504',
#  858: 'c8f069f7-fe41-41fe-8cda-bcf723704215',
#  859: '7900bc06-226e-4187-9c58-c371a2174934',
#  860: '23b3b94b-2362-46bc-b4b4-94bef57011a3',
#  861: '833a441a-157b-46cf-a1b6-e94e2bb8feea',
#  862: '86e9a4da-0d47-47f8-8fad-f300e2fb4454',
#  863: '3e731dbd-1a32-44fb-80f4-2d1fbe5d6a86',
#  864: '95e7cd4f-4b6f-44c2-aa92-c93748b97476',
#  865: '06302a80-21f3-42c4-8672-57b64e191cf7',
#  866: '8d1fab2d-2c38-4ed9-b48f-bed59823cf27',
#  867: '710d8dda-c6e6-4337-a3af-90a0ce7690f3',
#  868: '441938a2-fcfa-47c6-a190-910f76ffee3c',
#  869: '36f301b7-e4b0-4a8f-945a-c0ad192659fa',
#  870: '7292d7c5-bca1-45f2-9f9f-fd70f1ebfbb2',
#  871: '08b24027-81e4-4934-a3f0-bc3c5cdd6fba',
#  872: '21523cda-70ed-4baa-b53e-cc4043b0057b',
#  873: '51db9615-545b-4662-b617-9486f977f3fa',
#  874: '8631be55-902b-4213-a69d-832c43a95cab',
#  875: 'cf834702-07f7-4045-998c-077a4ae3fce8',
#  876: '0a4c34f7-f2b0-47d6-b6b5-4844baacd3a3',
#  877: '9fc26e8c-6f90-40e3-b068-1beead1bb0d8',
#  878: '38fdc993-8c3e-45ae-ac8e-ba214501f888',
#  879: '2ee009bf-71e3-43c7-b9ec-a89486ef23c6',
#  880: '2beb5b8f-feea-47b4-a245-d3e6d0d99f1c',
#  881: '0119668c-8d79-4309-a838-8236108e4087',
#  882: 'a39fdc3e-8392-40f3-9f80-8e8278a3ba49',
#  883: '36e1a895-8714-4d10-81ca-5a65ecbba45f',
#  884: '6e885743-d5f7-4f14-8c9b-6b76a97805bf',
#  885: '3042f65c-900d-4a3d-95f2-af2d6d3578df',
#  886: 'baff51d9-14fe-4c95-9e30-39567b8fe120',
#  887: '963f748b-6a26-4fd3-9497-c71b2cecc635',
#  888: '0e8f17ea-01ff-4c50-a5c8-24be56ef4d5c',
#  889: '6d5a4551-3ae1-45fb-a319-b3cf96e93b4a',
#  890: 'c282d012-82b1-44ac-ae1e-66aade45f35b',
#  891: '24c2fbfc-71fe-44d0-929c-4d89418d6d8b',
#  892: 'd25b3936-e033-4783-a1bd-77da0d037f0f',
#  893: 'f3626931-e96c-426f-aadf-81e4684008e0',
#  894: 'a8653df4-6097-4995-8b82-b0fe861466b5',
#  895: '61aceeb0-51ac-47be-9697-6e2bba1ec31b',
#  896: '413e7e69-8589-45f5-848b-2074609f63ac',
#  897: 'aaa23cee-c8d8-4de3-b92c-516ea844005f',
#  898: '3213f31b-fc42-40c4-bf45-a18664394266',
#  899: '9b2b7b16-bb52-45d9-be25-3352a9a3a270',
#  900: '738e5272-a3d3-4ff6-a262-40c296b4dbb4',
#  901: '0442dad7-2d86-4c2a-9507-53e08bdcbf3c',
#  902: 'a4cca63f-0212-45f5-832c-04ccb65112df',
#  903: '1af0e7c3-5625-4113-abba-ee5a9ff5c6e5',
#  904: '6f074a68-7809-4879-a209-c5e1f18dc303',
#  905: 'ee314cba-8e27-4932-8c23-64133f5fc0fd',
#  906: 'a2acc6a3-94e4-4111-bd27-396480c36938',
#  907: '81b4bacb-8929-46ff-a0c9-92889de90af9',
#  908: '5c100878-a7f2-49f0-a467-02a8e5af5a31',
#  909: 'df6509b1-6d3c-43f3-bdc7-858048071ddf',
#  910: 'd65ce738-ed98-440c-8997-a7f1847a9d0b',
#  911: '9f70eb63-3225-4c00-b436-d4ef06ccfdfd',
#  912: 'd8f19400-2c97-4bfb-a7ec-6794e1d58284',
#  913: 'd76fcdb1-1175-490e-b3b0-fb07ee536ada',
#  914: 'dda1d458-72dc-496f-9857-f556007cb284',
#  915: '7ea3ae74-da6d-48dc-91e4-d6ca95ec1cf7',
#  916: '84c9654a-3b91-4f27-be0f-c5b026fda094',
#  917: '966b3a05-4fde-4be0-9366-da395a597901',
#  918: 'e73e5275-0ef1-4ced-987f-e3f83489d0b7',
#  919: '36b13d4f-c6c3-4df4-b82a-73202a9a5deb',
#  920: '3fdda9a5-5f28-4b75-a890-1e52489cff1c',
#  921: 'c288180e-1cfb-4f72-8173-ff538594e33a',
#  922: '1e6d81f1-6cef-417e-8dd8-2125a62d18b8',
#  923: 'dcd91dd5-fdd1-423a-a0ae-2a3265c7261a',
#  924: 'da2b1313-a077-424b-a7d9-65c5b61ee231',
#  925: '35d2e8c3-5db0-43fe-a6fb-45c056b32d48',
#  926: '3b7dfd1c-3241-45e4-a4d5-987383036c6c',
#  927: 'f1fbae90-524e-469f-a329-a210f6144470',
#  928: 'f3c024a9-6d32-47be-b489-cbce3cd5c1d4',
#  929: '423d01a5-5aee-4f63-bb93-c494bea4b61b',
#  930: 'bbf21a99-a6d5-4bba-af75-a13cf357a1c5',
#  931: 'c9ee99c8-0703-4dd1-bf5f-a004bcd32b42',
#  932: '67c2173a-d529-42e2-9cb5-033025200fc6',
#  933: 'c04b329f-938c-464c-9320-f160fe727305',
#  934: 'fb868078-b28f-4d8f-89d7-9bbad6ad7634',
#  935: 'e7213952-f6af-40b7-938d-7ea8fcace135',
#  936: 'c32da91d-f6bb-405a-a999-fa09f9d11b94',
#  937: 'cb014807-ee9a-447b-a176-7dbf9c37f7ca',
#  938: 'e2d63e67-47c8-496e-9dd9-4c0caba5c754',
#  939: 'effccb11-972f-4ab7-940a-c53d5e779e2c',
#  940: '79488cad-f908-4616-85fe-70513ff76a09',
#  941: '5a922195-8900-4993-b10d-1e8aeb095a68',
#  942: '54a43032-3edc-4d38-8e00-7b0b395549c6',
#  989: 'eca4d294-205f-4d5b-98d3-911958a3c392',
#  990: '9b17aa00-b612-4bbf-aa3e-366d0f97e7cb',
#  991: '8557fc76-3b77-4bb5-b34f-0dce516fa2c6',
#  992: '8a9e53e5-1765-4bef-8010-6658d230f66e',
#  993: '9ece49d1-f5ee-4760-8759-48723a51fa69',
#  994: '276901e3-13c3-472d-b6e5-e41b7c5ddb80',
#  995: 'd6544873-8c5d-4749-b45f-a492ce2a7f43',
#  996: '834cb2b7-9686-4d08-b75b-1e9baccddef4',
#  997: '922d3f09-8eb0-42a2-8f1f-74540150e854',
#  998: '919f54b7-8dad-4927-bbd2-26f2d07c3868',
#  999: '0816a967-572a-4cd5-a018-c2f395968594',
#  ...}

# %%
vector_store.get_by_ids(['d87c9b26-c4c2-48de-9f68-40a4793677e0'])
# Out:
# []

# %% [markdown]
# # **2.Retrieval**

# %%
retriever = vector_store.as_retriever(
    search_type="mmr",
    search_kwargs={
        'k': 8,  # More documents
        'lambda_mult': 0.6,  # Balanced diversity
        'fetch_k': 20  # Larger candidate pool
    }
)

# %%
retriever
# Out:
# VectorStoreRetriever(tags=['FAISS', 'HuggingFaceEmbeddings'], vectorstore=<langchain_community.vectorstores.faiss.FAISS object at 0x7dd680c30110>, search_type='mmr', search_kwargs={'k': 8, 'lambda_mult': 0.6, 'fetch_k': 20})

# %%
retriever.invoke('what is deepmind')
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `BertSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# [Document(id='60841619-7951-49b9-b7c3-30e50d7216f4', metadata={}, page_content='deepmind originally was a confluence of'),
#  Document(id='45d1f6b5-1bfd-4b8c-a1bb-0880f676d9aa', metadata={}, page_content='deepmind um and my current thinking on'),
#  Document(id='1c8c3320-8e1e-407f-bc6c-86fa0926920f', metadata={}, page_content='interesting position where deepmind is'),
#  Document(id='c32da91d-f6bb-405a-a999-fa09f9d11b94', metadata={}, page_content='deepmind and what my career is being'),
#  Document(id='4104bba1-b946-42b3-8977-9785c927fe2d', metadata={}, page_content='big goal for deepmind how much of it is'),
#  Document(id='2d27cfd7-61e6-489b-9540-6c387d6c5da7', metadata={}, page_content='ceo and co-founder of deepmind'),
#  Document(id='d5e5bb28-4951-4b6d-9fe8-3d229ccb48e7', metadata={}, page_content='innovated with at deepmind to encourage'),
#  Document(id='a20a632e-0983-4301-97c6-56694910718d', metadata={}, page_content='start of deepmind was that we would use')]

# %% [markdown]
# # **3.Augmentation**

# %%
llm
# Out:
# ChatGroq(client=<groq.resources.chat.completions.Completions object at 0x7dd4edff16d0>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x7dd4e1171e90>, model_name='meta-llama/llama-4-scout-17b-16e-instruct', model_kwargs={}, groq_api_key=SecretStr('**********'))

# %%
prompt = PromptTemplate(
    template="""
    Analyze this context thoroughly:
    {context}

    Question: {question}

    Guidelines:
    1. If the name appears multiple times, identify all relevant positions
    2. Connect related information across chunks
    3. State if information is incomplete
    """,
    input_variables=['context', 'question']
)

# %%
question="is the topic of aliens discussed in this video ? if yes then what was discussed?"
retrieved_docs=retriever.invoke(question)
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `BertSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)

# %%
context_text=f" \n\n ".join(doc.page_content for doc in retrieved_docs)

# %%
final_prompt=prompt.invoke({"context":context_text,"question":question})

# %% [markdown]
# # **4.Generation**

# %%
retrieved_docs
# Out:
# [Document(id='4356e48c-f710-44ab-9056-48e117d8dec0', metadata={}, page_content="do you think there's a lot of alien"),
#  Document(id='9383ad0c-522f-4a3b-9a15-6055608e2ab0', metadata={}, page_content='what we spoke about at the beginning'),
#  Document(id='b2f21b2f-789b-4695-b512-816170e65180', metadata={}, page_content='and it was projected by the aliens or'),
#  Document(id='5d5b30a6-69f4-4ec7-b0df-d96ff139a3b2', metadata={}, page_content='forever right and sci-fi has talked'),
#  Document(id='2f34c400-e07a-4c94-974e-3dc12893b642', metadata={}, page_content='other explanation did was there um 2001'),
#  Document(id='d6e62bc7-f088-4572-95f3-c770731f5937', metadata={}, page_content="dawning of the the space age uh we've"),
#  Document(id='f32be65c-6e91-4763-8075-930e38894b23', metadata={}, page_content="aliens would say well we haven't really"),
#  Document(id='ed8e2829-f8dc-40c1-bbdc-cc89889ca8c3', metadata={}, page_content='it was a it was a really interesting it')]

# %%
context_text
# Out:
# "do you think there's a lot of alien \n\n what we spoke about at the beginning \n\n and it was projected by the aliens or \n\n forever right and sci-fi has talked \n\n other explanation did was there um 2001 \n\n dawning of the the space age uh we've \n\n aliens would say well we haven't really \n\n it was a it was a really interesting it"

# %%
final_prompt
# Out:
# StringPromptValue(text="\n    Analyze this context thoroughly:\n    do you think there's a lot of alien \n\n what we spoke about at the beginning \n\n and it was projected by the aliens or \n\n forever right and sci-fi has talked \n\n other explanation did was there um 2001 \n\n dawning of the the space age uh we've \n\n aliens would say well we haven't really \n\n it was a it was a really interesting it\n    \n    Question: is the topic of aliens discussed in this video ? if yes then what was discussed?\n    \n    Guidelines:\n    1. If the name appears multiple times, identify all relevant positions\n    2. Connect related information across chunks\n    3. State if information is incomplete\n    ")

# %%
answer=llm.invoke(final_prompt)
print(answer)
# Out:
# content='After thoroughly analyzing the context, I can conclude that:\n\n**Yes, the topic of aliens is discussed in this video.**\n\nHere\'s a breakdown of the relevant information:\n\n1. The topic of aliens is first mentioned in the phrase "do you think there\'s a lot of alien".\n2. The speaker then seems to connect the idea of aliens to a previous conversation, mentioning "what we spoke about at the beginning".\n3. The speaker suggests that this previous conversation might have been "projected by the aliens".\n4. The discussion appears to be related to science fiction (sci-fi), which has explored the idea of aliens, as mentioned in the phrase "sci-fi has talked".\n5. The speaker also references a specific example, "2001: A Space Odyssey" (implied by "um2001"), which is a classic sci-fi movie that explores the theme of aliens and space.\n6. The speaker seems to be considering alternative explanations for something, mentioning "other explanation did was there".\n7. The aliens are quoted as saying "we haven\'t really" (implying that they might not be directly involved or responsible for something).\n\n**Relevant positions:**\n\n* Aliens: mentioned in positions 1, 3, 4, 5, and 7.\n* Related concepts: sci-fi (position 4), space age (position 5), and 2001: A Space Odyssey (position 5).\n\n**Information completeness:**\nThe information appears to be incomplete, as the conversation seems to be a fragment of a larger discussion. The speaker is building on previous conversations and ideas, but the context and conclusions are not fully elaborated.' additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 334, 'prompt_tokens': 138, 'total_tokens': 472, 'completion_time': 0.76355991, 'prompt_time': 0.006110853, 'queue_time': 0.195745189, 'total_time': 0.769670763}, 'model_name': 'meta-llama/llama-4-scout-17b-16e-instruct', 'system_fingerprint': 'fp_37da608fc1', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None} id='run--04f91740-d783-4649-a85f-839024c05209-0' usage_metadata={'input_tokens': 138, 'output_tokens': 334, 'total_tokens': 472}

# %%
print(answer.content)
# Out:
# After thoroughly analyzing the context, I can conclude that:
#
# **Yes, the topic of aliens is discussed in this video.**
#
# Here's a breakdown of the relevant information:
#
# 1. The topic of aliens is first mentioned in the phrase "do you think there's a lot of alien".
# 2. The speaker then seems to connect the idea of aliens to a previous conversation, mentioning "what we spoke about at the beginning".
# 3. The speaker suggests that this previous conversation might have been "projected by the aliens".
# 4. The discussion appears to be related to science fiction (sci-fi), which has explored the idea of aliens, as mentioned in the phrase "sci-fi has talked".
# 5. The speaker also references a specific example, "2001: A Space Odyssey" (implied by "um2001"), which is a classic sci-fi movie that explores the theme of aliens and space.
# 6. The speaker seems to be considering alternative explanations for something, mentioning "other explanation did was there".
# 7. The aliens are quoted as saying "we haven't really" (implying that they might not be directly involved or responsible for something).
#
# **Relevant positions:**
#
# * Aliens: mentioned in positions 1, 3, 4, 5, and 7.
# * Related concepts: sci-fi (position 4), space age (position 5), and 2001: A Space Odyssey (position 5).
#
# **Information completeness:**
# The information appears to be incomplete, as the conversation seems to be a fragment of a larger discussion. The speaker is building on previous conversations and ideas, but the context and conclusions are not fully elaborated.

# %% [markdown]
# # 5.Building a **Chain**

# %%
from langchain_core.runnables import RunnableParallel,RunnableSequence,RunnablePassthrough
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnableLambda

# %%
def format_docs(retrieved_docs):
  context_text="\n\n".join(doc.page_content for doc in retrieved_docs)
  return context_text

# %%
parallel_chain=RunnableParallel({
    'context':retriever | RunnableLambda(format_docs),
    'question':RunnablePassthrough()
})

# %%
parallel_chain.invoke('who is demis')
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `BertSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `BertSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# {'context': "here's demis\n\nceo and co-founder of deepmind\n\nand and actually levantal who is another\n\nthe world to judith polgar who obviously\n\nobviously nick bostrom i think famously\n\nconversation with demas establish to\n\nher to have a life they can be proud of\n\nconsciousness gravity",
#  'question': 'who is demis'}

# %%
parser=StrOutputParser()

# %%
main_chain=parallel_chain | prompt| llm |parser

# %%
main_chain.invoke("Can you summarize the video")
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `BertSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `BertSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# 'After thoroughly analyzing the context, here is a summarization of the information:\n\n**Summary:** The speaker appears to be discussing a video or animation that explains how something works. They express their enjoyment and amazement at seeing the animation, stating it was "incredible" and "pretty much amazing to see."\n\n**Key Points:**\n\n* The speaker mentions a video/animation that explains how something works.\n* They express their enthusiasm and appreciation for the video, thanking someone named "Lex".\n* The speaker is asked if they can summarize the video and explain how it works.\n* The speaker seems to be having a conversation with someone, possibly Lex, and is asked to analyze something, but they interrupt to say they have to run.\n\n**Positions of Names:**\n\n* "Lex" is mentioned once, as someone the speaker is conversing with and thanking.\n\n**Related Information:**\n\n* The speaker\'s enthusiasm and appreciation for the video/animation are connected across chunks, suggesting that they found it engaging and informative.\n* The speaker\'s conversation with Lex is connected across chunks, indicating that they are discussing the video/animation and its explanation.\n\n**Completeness of Information:**\n\n* The information is incomplete, as the speaker does not provide a detailed summary of the video or a thorough explanation of how it works. The conversation appears to be cut off, with the speaker saying they "have to run."'
