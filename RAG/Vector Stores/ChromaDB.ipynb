# %%
pip install chromadb
# Out:
# Collecting chromadb
#   Downloading chromadb-1.0.15-cp39-abi3-win_amd64.whl.metadata (7.1 kB)
# Collecting build>=1.0.3 (from chromadb)
#   Downloading build-1.2.2.post1-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: pydantic>=1.9 in c:\users\niraj\anaconda3\lib\site-packages (from chromadb) (2.8.2)
# Collecting pybase64>=1.4.1 (from chromadb)
#   Downloading pybase64-1.4.2-cp312-cp312-win_amd64.whl.metadata (9.0 kB)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\niraj\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.35.0)
# Requirement already satisfied: numpy>=1.22.5 in c:\users\niraj\anaconda3\lib\site-packages (from chromadb) (1.26.4)
# Collecting posthog<6.0.0,>=2.4.0 (from chromadb)
#   Downloading posthog-5.4.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\niraj\anaconda3\lib\site-packages (from chromadb) (4.14.1)
# Collecting onnxruntime>=1.14.1 (from chromadb)
#   Downloading onnxruntime-1.22.1-cp312-cp312-win_amd64.whl.metadata (5.1 kB)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\niraj\anaconda3\lib\site-packages (from chromadb) (1.35.0)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.36.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\niraj\anaconda3\lib\site-packages (from chromadb) (1.35.0)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\niraj\anaconda3\lib\site-packages (from chromadb) (0.21.2)
# Collecting pypika>=0.48.9 (from chromadb)
#   Downloading PyPika-0.48.9.tar.gz (67 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\niraj\anaconda3\lib\site-packages (from chromadb) (4.66.5)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\niraj\anaconda3\lib\site-packages (from chromadb) (7.4.0)
# Collecting importlib-resources (from chromadb)
#   Downloading importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\niraj\anaconda3\lib\site-packages (from chromadb) (1.72.1)
# Collecting bcrypt>=4.0.1 (from chromadb)
#   Downloading bcrypt-4.3.0-cp39-abi3-win_amd64.whl.metadata (10 kB)
# Requirement already satisfied: typer>=0.9.0 in c:\users\niraj\anaconda3\lib\site-packages (from chromadb) (0.9.0)
# Collecting kubernetes>=28.1.0 (from chromadb)
#   Downloading kubernetes-33.1.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\niraj\anaconda3\lib\site-packages (from chromadb) (8.2.3)
# Requirement already satisfied: pyyaml>=6.0.0 in c:\users\niraj\anaconda3\lib\site-packages (from chromadb) (6.0.1)
# Collecting mmh3>=4.0.1 (from chromadb)
#   Downloading mmh3-5.2.0-cp312-cp312-win_amd64.whl.metadata (14 kB)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\niraj\anaconda3\lib\site-packages (from chromadb) (3.11.0)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\niraj\anaconda3\lib\site-packages (from chromadb) (0.27.0)
# Requirement already satisfied: rich>=10.11.0 in c:\users\niraj\anaconda3\lib\site-packages (from chromadb) (13.7.1)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\users\niraj\anaconda3\lib\site-packages (from chromadb) (4.23.0)
# Requirement already satisfied: requests<3.0,>=2.7 in c:\users\niraj\anaconda3\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.32.3)
# Requirement already satisfied: six>=1.5 in c:\users\niraj\anaconda3\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.2 in c:\users\niraj\anaconda3\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.9.0.post0)
# Collecting backoff>=1.10.0 (from posthog<6.0.0,>=2.4.0->chromadb)
#   Using cached backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: distro>=1.5.0 in c:\users\niraj\anaconda3\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\niraj\anaconda3\lib\site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\niraj\anaconda3\lib\site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\niraj\anaconda3\lib\site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\niraj\anaconda3\lib\site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (2025.7.14)
# Requirement already satisfied: packaging>=19.1 in c:\users\niraj\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (24.1)
# Collecting pyproject_hooks (from build>=1.0.3->chromadb)
#   Downloading pyproject_hooks-1.2.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: colorama in c:\users\niraj\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: anyio in c:\users\niraj\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (4.2.0)
# Requirement already satisfied: httpcore==1.* in c:\users\niraj\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (1.0.2)
# Requirement already satisfied: sniffio in c:\users\niraj\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\niraj\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.14.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\niraj\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\niraj\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\niraj\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\niraj\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.10.6)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\niraj\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.40.3)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\niraj\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Collecting requests-oauthlib (from kubernetes>=28.1.0->chromadb)
#   Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Collecting oauthlib>=3.2.2 (from kubernetes>=28.1.0->chromadb)
#   Using cached oauthlib-3.3.1-py3-none-any.whl.metadata (7.9 kB)
# Collecting durationpy>=0.7 (from kubernetes>=28.1.0->chromadb)
#   Downloading durationpy-0.10-py3-none-any.whl.metadata (340 bytes)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\niraj\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\niraj\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\niraj\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\niraj\anaconda3\lib\site-packages (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.8)
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in c:\users\niraj\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (25.2.10)
# Requirement already satisfied: protobuf in c:\users\niraj\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (5.29.5)
# Requirement already satisfied: sympy in c:\users\niraj\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.14.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\niraj\anaconda3\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (7.0.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\niraj\anaconda3\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.17.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in c:\users\niraj\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.70.0)
# Collecting opentelemetry-exporter-otlp-proto-common==1.36.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_common-1.36.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting opentelemetry-proto==1.36.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_proto-1.36.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb)
#   Downloading opentelemetry_sdk-1.36.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-api>=1.2.0 (from chromadb)
#   Downloading opentelemetry_api-1.36.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-semantic-conventions==0.57b0 (from opentelemetry-sdk>=1.2.0->chromadb)
#   Downloading opentelemetry_semantic_conventions-0.57b0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\niraj\anaconda3\lib\site-packages (from pydantic>=1.9->chromadb) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\niraj\anaconda3\lib\site-packages (from pydantic>=1.9->chromadb) (2.20.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\niraj\anaconda3\lib\site-packages (from rich>=10.11.0->chromadb) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\niraj\appdata\roaming\python\python312\site-packages (from rich>=10.11.0->chromadb) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\niraj\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\niraj\anaconda3\lib\site-packages (from tokenizers>=0.13.2->chromadb) (0.33.4)
# Requirement already satisfied: filelock in c:\users\niraj\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\niraj\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2024.6.1)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\niraj\anaconda3\lib\site-packages (from typer>=0.9.0->chromadb) (8.1.7)
# Collecting httptools>=0.6.3 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading httptools-0.6.4-cp312-cp312-win_amd64.whl.metadata (3.7 kB)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\niraj\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.21.0)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading watchfiles-1.1.0-cp312-cp312-win_amd64.whl.metadata (5.0 kB)
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.18.3->chromadb)
#   Using cached websockets-15.0.1-cp312-cp312-win_amd64.whl.metadata (7.0 kB)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Collecting pyreadline3 (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb)
#   Downloading pyreadline3-3.5.4-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\niraj\anaconda3\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Downloading chromadb-1.0.15-cp39-abi3-win_amd64.whl (19.5 MB)
#    ---------------------------------------- 0.0/19.5 MB ? eta -:--:--
#     --------------------------------------- 0.3/19.5 MB ? eta -:--:--
#    - -------------------------------------- 0.5/19.5 MB 1.4 MB/s eta 0:00:14
#    - -------------------------------------- 0.5/19.5 MB 1.4 MB/s eta 0:00:14
#    - -------------------------------------- 0.8/19.5 MB 958.5 kB/s eta 0:00:20
#    -- ------------------------------------- 1.0/19.5 MB 1.0 MB/s eta 0:00:19
#    --- ------------------------------------ 1.6/19.5 MB 1.2 MB/s eta 0:00:15
#    ---- ----------------------------------- 2.1/19.5 MB 1.4 MB/s eta 0:00:13
#    ----- ---------------------------------- 2.9/19.5 MB 1.7 MB/s eta 0:00:10
#    -------- ------------------------------- 3.9/19.5 MB 2.1 MB/s eta 0:00:08
#    --------- ------------------------------ 4.5/19.5 MB 2.2 MB/s eta 0:00:07
#    ---------- ----------------------------- 5.2/19.5 MB 2.3 MB/s eta 0:00:07
#    ----------- ---------------------------- 5.8/19.5 MB 2.4 MB/s eta 0:00:06
#    ------------- -------------------------- 6.8/19.5 MB 2.6 MB/s eta 0:00:05
#    --------------- ------------------------ 7.6/19.5 MB 2.7 MB/s eta 0:00:05
#    ----------------- ---------------------- 8.7/19.5 MB 2.8 MB/s eta 0:00:04
#    ------------------- -------------------- 9.4/19.5 MB 2.9 MB/s eta 0:00:04
#    -------------------- ------------------- 10.2/19.5 MB 2.9 MB/s eta 0:00:04
#    ---------------------- ----------------- 10.7/19.5 MB 3.0 MB/s eta 0:00:03
#    ---------------------- ----------------- 11.0/19.5 MB 2.9 MB/s eta 0:00:03
#    ---------------------- ----------------- 11.0/19.5 MB 2.9 MB/s eta 0:00:03
#    ----------------------- ---------------- 11.3/19.5 MB 2.6 MB/s eta 0:00:04
#    ----------------------- ---------------- 11.5/19.5 MB 2.5 MB/s eta 0:00:04
#    ------------------------ --------------- 11.8/19.5 MB 2.5 MB/s eta 0:00:04
#    ------------------------ --------------- 11.8/19.5 MB 2.5 MB/s eta 0:00:04
#    ------------------------ --------------- 12.1/19.5 MB 2.3 MB/s eta 0:00:04
#    ------------------------- -------------- 12.3/19.5 MB 2.3 MB/s eta 0:00:04
#    ------------------------- -------------- 12.6/19.5 MB 2.2 MB/s eta 0:00:04
#    -------------------------- ------------- 12.8/19.5 MB 2.2 MB/s eta 0:00:04
#    --------------------------- ------------ 13.4/19.5 MB 2.2 MB/s eta 0:00:03
#    --------------------------- ------------ 13.6/19.5 MB 2.2 MB/s eta 0:00:03
#    ----------------------------- ---------- 14.2/19.5 MB 2.2 MB/s eta 0:00:03
#    ----------------------------- ---------- 14.4/19.5 MB 2.2 MB/s eta 0:00:03
#    ------------------------------- -------- 15.2/19.5 MB 2.2 MB/s eta 0:00:02
#    -------------------------------- ------- 15.7/19.5 MB 2.2 MB/s eta 0:00:02
#    ---------------------------------- ----- 16.8/19.5 MB 2.3 MB/s eta 0:00:02
#    ----------------------------------- ---- 17.6/19.5 MB 2.3 MB/s eta 0:00:01
#    -------------------------------------- - 18.6/19.5 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------------  19.4/19.5 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------------- 19.5/19.5 MB 2.4 MB/s  0:00:08
# Downloading posthog-5.4.0-py3-none-any.whl (105 kB)
# Using cached backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading bcrypt-4.3.0-cp39-abi3-win_amd64.whl (152 kB)
# Downloading build-1.2.2.post1-py3-none-any.whl (22 kB)
# Downloading kubernetes-33.1.0-py2.py3-none-any.whl (1.9 MB)
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    ---------- ----------------------------- 0.5/1.9 MB 3.3 MB/s eta 0:00:01
#    --------------------- ------------------ 1.0/1.9 MB 3.1 MB/s eta 0:00:01
#    -------------------------------- ------- 1.6/1.9 MB 2.8 MB/s eta 0:00:01
#    ---------------------------------------- 1.9/1.9 MB 2.5 MB/s  0:00:00
# Downloading durationpy-0.10-py3-none-any.whl (3.9 kB)
# Downloading mmh3-5.2.0-cp312-cp312-win_amd64.whl (41 kB)
# Using cached oauthlib-3.3.1-py3-none-any.whl (160 kB)
# Downloading onnxruntime-1.22.1-cp312-cp312-win_amd64.whl (12.7 MB)
#    ---------------------------------------- 0.0/12.7 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.7 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/12.7 MB 2.2 MB/s eta 0:00:06
#    ---- ----------------------------------- 1.3/12.7 MB 2.4 MB/s eta 0:00:05
#    ---- ----------------------------------- 1.6/12.7 MB 2.4 MB/s eta 0:00:05
#    ------ --------------------------------- 2.1/12.7 MB 2.2 MB/s eta 0:00:05
#    -------- ------------------------------- 2.6/12.7 MB 2.3 MB/s eta 0:00:05
#    --------- ------------------------------ 3.1/12.7 MB 2.3 MB/s eta 0:00:05
#    ----------- ---------------------------- 3.7/12.7 MB 2.4 MB/s eta 0:00:04
#    -------------- ------------------------- 4.7/12.7 MB 2.7 MB/s eta 0:00:03
#    ---------------- ----------------------- 5.2/12.7 MB 2.7 MB/s eta 0:00:03
#    ------------------- -------------------- 6.0/12.7 MB 2.8 MB/s eta 0:00:03
#    ---------------------- ----------------- 7.1/12.7 MB 3.0 MB/s eta 0:00:02
#    ------------------------- -------------- 8.1/12.7 MB 3.2 MB/s eta 0:00:02
#    ---------------------------- ----------- 8.9/12.7 MB 3.3 MB/s eta 0:00:02
#    ----------------------------- ---------- 9.4/12.7 MB 3.3 MB/s eta 0:00:01
#    ------------------------------ --------- 9.7/12.7 MB 3.2 MB/s eta 0:00:01
#    ------------------------------ --------- 9.7/12.7 MB 3.2 MB/s eta 0:00:01
#    ------------------------------ --------- 9.7/12.7 MB 3.2 MB/s eta 0:00:01
#    ------------------------------ --------- 9.7/12.7 MB 3.2 MB/s eta 0:00:01
#    ------------------------------ --------- 9.7/12.7 MB 3.2 MB/s eta 0:00:01
#    ------------------------------ --------- 9.7/12.7 MB 3.2 MB/s eta 0:00:01
#    ------------------------------ --------- 9.7/12.7 MB 3.2 MB/s eta 0:00:01
#    ------------------------------- -------- 10.0/12.7 MB 2.2 MB/s eta 0:00:02
#    --------------------------------- ------ 10.5/12.7 MB 2.1 MB/s eta 0:00:02
#    ---------------------------------- ----- 11.0/12.7 MB 2.1 MB/s eta 0:00:01
#    ------------------------------------ --- 11.5/12.7 MB 2.2 MB/s eta 0:00:01
#    -------------------------------------- - 12.1/12.7 MB 2.2 MB/s eta 0:00:01
#    ---------------------------------------- 12.7/12.7 MB 2.2 MB/s  0:00:05
# Downloading opentelemetry_exporter_otlp_proto_grpc-1.36.0-py3-none-any.whl (18 kB)
# Downloading opentelemetry_exporter_otlp_proto_common-1.36.0-py3-none-any.whl (18 kB)
# Downloading opentelemetry_proto-1.36.0-py3-none-any.whl (72 kB)
# Downloading opentelemetry_sdk-1.36.0-py3-none-any.whl (119 kB)
# Downloading opentelemetry_api-1.36.0-py3-none-any.whl (65 kB)
# Downloading opentelemetry_semantic_conventions-0.57b0-py3-none-any.whl (201 kB)
# Downloading pybase64-1.4.2-cp312-cp312-win_amd64.whl (35 kB)
# Downloading httptools-0.6.4-cp312-cp312-win_amd64.whl (88 kB)
# Downloading watchfiles-1.1.0-cp312-cp312-win_amd64.whl (292 kB)
# Using cached websockets-15.0.1-cp312-cp312-win_amd64.whl (176 kB)
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Downloading importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Downloading pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Downloading pyreadline3-3.5.4-py3-none-any.whl (83 kB)
# Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Building wheels for collected packages: pypika
#   Building wheel for pypika (pyproject.toml): started
#   Building wheel for pypika (pyproject.toml): finished with status 'done'
#   Created wheel for pypika: filename=pypika-0.48.9-py2.py3-none-any.whl size=53916 sha256=dcdc17e8bde0ef2bb43d46875edf46b38322b33a79b576e49e62f2e61c201f61
#   Stored in directory: c:\users\niraj\appdata\local\pip\cache\wheels\d5\3d\69\8d68d249cd3de2584f226e27fd431d6344f7d70fd856ebd01b
# Successfully built pypika
# Installing collected packages: pypika, durationpy, websockets, pyreadline3, pyproject_hooks, pybase64, opentelemetry-proto, oauthlib, mmh3, importlib-resources, httptools, bcrypt, backoff, watchfiles, requests-oauthlib, posthog, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, humanfriendly, build, opentelemetry-semantic-conventions, kubernetes, coloredlogs, opentelemetry-sdk, onnxruntime, opentelemetry-exporter-otlp-proto-grpc, chromadb
#
#    -- -------------------------------------  2/27 [websockets]
#    -- -------------------------------------  2/27 [websockets]
#    ---- -----------------------------------  3/27 [pyreadline3]
#    ---------- -----------------------------  7/27 [oauthlib]
#    ---------- -----------------------------  7/27 [oauthlib]
#    -------------- ------------------------- 10/27 [httptools]
#   Attempting uninstall: bcrypt
#    -------------- ------------------------- 10/27 [httptools]
#     Found existing installation: bcrypt 3.2.0
#    -------------- ------------------------- 10/27 [httptools]
#     Uninstalling bcrypt-3.2.0:
#    -------------- ------------------------- 10/27 [httptools]
#       Successfully uninstalled bcrypt-3.2.0
#    -------------- ------------------------- 10/27 [httptools]
#    -------------------- ------------------- 14/27 [requests-oauthlib]
#    ---------------------- ----------------- 15/27 [posthog]
#   Attempting uninstall: opentelemetry-api
#    ---------------------- ----------------- 15/27 [posthog]
#     Found existing installation: opentelemetry-api 1.35.0
#    ---------------------- ----------------- 15/27 [posthog]
#    ------------------------- -------------- 17/27 [opentelemetry-api]
#     Uninstalling opentelemetry-api-1.35.0:
#    ------------------------- -------------- 17/27 [opentelemetry-api]
#       Successfully uninstalled opentelemetry-api-1.35.0
#    ------------------------- -------------- 17/27 [opentelemetry-api]
#    ------------------------- -------------- 17/27 [opentelemetry-api]
#    ---------------------------- ----------- 19/27 [build]
#   Attempting uninstall: opentelemetry-semantic-conventions
#    ---------------------------- ----------- 19/27 [build]
#     Found existing installation: opentelemetry-semantic-conventions 0.56b0
#    ---------------------------- ----------- 19/27 [build]
#     Uninstalling opentelemetry-semantic-conventions-0.56b0:
#    ---------------------------- ----------- 19/27 [build]
#       Successfully uninstalled opentelemetry-semantic-conventions-0.56b0
#    ---------------------------- ----------- 19/27 [build]
#    ------------------------ -------- 20/27 [opentelemetry-semantic-conventions]
#    ------------------------ -------- 20/27 [opentelemetry-semantic-conventions]
#    ------------------------------- -------- 21/27 [kubernetes]
#    ------------------------------- -------- 21/27 [kubernetes]
#    ------------------------------- -------- 21/27 [kubernetes]
#    ------------------------------- -------- 21/27 [kubernetes]
#    ------------------------------- -------- 21/27 [kubernetes]
#    ------------------------------- -------- 21/27 [kubernetes]
#    ------------------------------- -------- 21/27 [kubernetes]
#    ------------------------------- -------- 21/27 [kubernetes]
#    ------------------------------- -------- 21/27 [kubernetes]
#    ------------------------------- -------- 21/27 [kubernetes]
#    ------------------------------- -------- 21/27 [kubernetes]
#    ------------------------------- -------- 21/27 [kubernetes]
#    ------------------------------- -------- 21/27 [kubernetes]
#    ------------------------------- -------- 21/27 [kubernetes]
#    ------------------------------- -------- 21/27 [kubernetes]
#    ------------------------------- -------- 21/27 [kubernetes]
#    ------------------------------- -------- 21/27 [kubernetes]
#    ------------------------------- -------- 21/27 [kubernetes]
#    ------------------------------- -------- 21/27 [kubernetes]
#    ------------------------------- -------- 21/27 [kubernetes]
#    ------------------------------- -------- 21/27 [kubernetes]
#    ------------------------------- -------- 21/27 [kubernetes]
#   Attempting uninstall: opentelemetry-sdk
#    ------------------------------- -------- 21/27 [kubernetes]
#    ---------------------------------- ----- 23/27 [opentelemetry-sdk]
#     Found existing installation: opentelemetry-sdk 1.35.0
#    ---------------------------------- ----- 23/27 [opentelemetry-sdk]
#     Uninstalling opentelemetry-sdk-1.35.0:
#    ---------------------------------- ----- 23/27 [opentelemetry-sdk]
#       Successfully uninstalled opentelemetry-sdk-1.35.0
#    ---------------------------------- ----- 23/27 [opentelemetry-sdk]
#    ---------------------------------- ----- 23/27 [opentelemetry-sdk]
#    ----------------------------------- ---- 24/27 [onnxruntime]
#    ----------------------------------- ---- 24/27 [onnxruntime]
#    ----------------------------------- ---- 24/27 [onnxruntime]
#    ----------------------------------- ---- 24/27 [onnxruntime]
#    ----------------------------------- ---- 24/27 [onnxruntime]
#    ----------------------------------- ---- 24/27 [onnxruntime]
#    ----------------------------------- ---- 24/27 [onnxruntime]
#    ----------------------------------- ---- 24/27 [onnxruntime]
#    ----------------------------------- ---- 24/27 [onnxruntime]
#    ----------------------------------- ---- 24/27 [onnxruntime]
#    -------------------------------------- - 26/27 [chromadb]
#    -------------------------------------- - 26/27 [chromadb]
#    -------------------------------------- - 26/27 [chromadb]
#    -------------------------------------- - 26/27 [chromadb]
#    -------------------------------------- - 26/27 [chromadb]
#    -------------------------------------- - 26/27 [chromadb]
#    -------------------------------------- - 26/27 [chromadb]
#    ---------------------------------------- 27/27 [chromadb]
#
# Successfully installed backoff-2.2.1 bcrypt-4.3.0 build-1.2.2.post1 chromadb-1.0.15 coloredlogs-15.0.1 durationpy-0.10 httptools-0.6.4 humanfriendly-10.0 importlib-resources-6.5.2 kubernetes-33.1.0 mmh3-5.2.0 oauthlib-3.3.1 onnxruntime-1.22.1 opentelemetry-api-1.36.0 opentelemetry-exporter-otlp-proto-common-1.36.0 opentelemetry-exporter-otlp-proto-grpc-1.36.0 opentelemetry-proto-1.36.0 opentelemetry-sdk-1.36.0 opentelemetry-semantic-conventions-0.57b0 posthog-5.4.0 pybase64-1.4.2 pypika-0.48.9 pyproject_hooks-1.2.0 pyreadline3-3.5.4 requests-oauthlib-2.0.0 watchfiles-1.1.0 websockets-15.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install sentence-transformers
# Out:
# Requirement already satisfied: sentence-transformers in c:\users\niraj\anaconda3\lib\site-packages (5.0.0)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in c:\users\niraj\anaconda3\lib\site-packages (from sentence-transformers) (4.53.2)
# Requirement already satisfied: tqdm in c:\users\niraj\anaconda3\lib\site-packages (from sentence-transformers) (4.66.5)
# Requirement already satisfied: torch>=1.11.0 in c:\users\niraj\anaconda3\lib\site-packages (from sentence-transformers) (2.7.1)
# Requirement already satisfied: scikit-learn in c:\users\niraj\anaconda3\lib\site-packages (from sentence-transformers) (1.5.1)
# Requirement already satisfied: scipy in c:\users\niraj\anaconda3\lib\site-packages (from sentence-transformers) (1.13.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\niraj\anaconda3\lib\site-packages (from sentence-transformers) (0.33.4)
# Requirement already satisfied: Pillow in c:\users\niraj\anaconda3\lib\site-packages (from sentence-transformers) (10.4.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\niraj\anaconda3\lib\site-packages (from sentence-transformers) (4.14.1)
# Requirement already satisfied: filelock in c:\users\niraj\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (3.13.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\niraj\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\niraj\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\niraj\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\niraj\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.9.11)
# Requirement already satisfied: requests in c:\users\niraj\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\niraj\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.21.2)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\niraj\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.5.3)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\niraj\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2024.6.1)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\niraj\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx in c:\users\niraj\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.3)
# Requirement already satisfied: jinja2 in c:\users\niraj\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.4)
# Requirement already satisfied: setuptools in c:\users\niraj\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (75.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\niraj\anaconda3\lib\site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: colorama in c:\users\niraj\anaconda3\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\niraj\anaconda3\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\niraj\anaconda3\lib\site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\niraj\anaconda3\lib\site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\niraj\anaconda3\lib\site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\niraj\anaconda3\lib\site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (2025.7.14)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\niraj\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\niraj\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install codecarbon
# Out:
# Collecting codecarbon
#   Downloading codecarbon-3.0.4-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: arrow in c:\users\niraj\anaconda3\lib\site-packages (from codecarbon) (1.2.3)
# Requirement already satisfied: click in c:\users\niraj\anaconda3\lib\site-packages (from codecarbon) (8.1.7)
# Collecting fief-client[cli] (from codecarbon)
#   Downloading fief_client-0.20.0-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: pandas in c:\users\niraj\anaconda3\lib\site-packages (from codecarbon) (2.3.1)
# Requirement already satisfied: prometheus_client in c:\users\niraj\anaconda3\lib\site-packages (from codecarbon) (0.14.1)
# Requirement already satisfied: psutil>=6.0.0 in c:\users\niraj\appdata\roaming\python\python312\site-packages (from codecarbon) (6.0.0)
# Requirement already satisfied: py-cpuinfo in c:\users\niraj\anaconda3\lib\site-packages (from codecarbon) (9.0.0)
# Requirement already satisfied: pydantic in c:\users\niraj\anaconda3\lib\site-packages (from codecarbon) (2.8.2)
# Collecting pynvml (from codecarbon)
#   Using cached pynvml-12.0.0-py3-none-any.whl.metadata (5.4 kB)
# Collecting rapidfuzz (from codecarbon)
#   Downloading rapidfuzz-3.13.0-cp312-cp312-win_amd64.whl.metadata (12 kB)
# Requirement already satisfied: requests in c:\users\niraj\anaconda3\lib\site-packages (from codecarbon) (2.32.3)
# Collecting questionary (from codecarbon)
#   Downloading questionary-2.1.0-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: rich in c:\users\niraj\anaconda3\lib\site-packages (from codecarbon) (13.7.1)
# Requirement already satisfied: typer in c:\users\niraj\anaconda3\lib\site-packages (from codecarbon) (0.9.0)
# Requirement already satisfied: python-dateutil>=2.7.0 in c:\users\niraj\anaconda3\lib\site-packages (from arrow->codecarbon) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\niraj\anaconda3\lib\site-packages (from python-dateutil>=2.7.0->arrow->codecarbon) (1.16.0)
# Requirement already satisfied: colorama in c:\users\niraj\anaconda3\lib\site-packages (from click->codecarbon) (0.4.6)
# Requirement already satisfied: httpx<0.28.0,>=0.21.3 in c:\users\niraj\anaconda3\lib\site-packages (from fief-client[cli]->codecarbon) (0.27.0)
# Collecting jwcrypto<2.0.0,>=1.4 (from fief-client[cli]->codecarbon)
#   Downloading jwcrypto-1.5.6-py3-none-any.whl.metadata (3.1 kB)
# Collecting yaspin (from fief-client[cli]->codecarbon)
#   Downloading yaspin-3.1.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: anyio in c:\users\niraj\anaconda3\lib\site-packages (from httpx<0.28.0,>=0.21.3->fief-client[cli]->codecarbon) (4.2.0)
# Requirement already satisfied: certifi in c:\users\niraj\anaconda3\lib\site-packages (from httpx<0.28.0,>=0.21.3->fief-client[cli]->codecarbon) (2025.7.14)
# Requirement already satisfied: httpcore==1.* in c:\users\niraj\anaconda3\lib\site-packages (from httpx<0.28.0,>=0.21.3->fief-client[cli]->codecarbon) (1.0.2)
# Requirement already satisfied: idna in c:\users\niraj\anaconda3\lib\site-packages (from httpx<0.28.0,>=0.21.3->fief-client[cli]->codecarbon) (3.7)
# Requirement already satisfied: sniffio in c:\users\niraj\anaconda3\lib\site-packages (from httpx<0.28.0,>=0.21.3->fief-client[cli]->codecarbon) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\niraj\anaconda3\lib\site-packages (from httpcore==1.*->httpx<0.28.0,>=0.21.3->fief-client[cli]->codecarbon) (0.14.0)
# Requirement already satisfied: cryptography>=3.4 in c:\users\niraj\anaconda3\lib\site-packages (from jwcrypto<2.0.0,>=1.4->fief-client[cli]->codecarbon) (43.0.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\niraj\anaconda3\lib\site-packages (from jwcrypto<2.0.0,>=1.4->fief-client[cli]->codecarbon) (4.14.1)
# Requirement already satisfied: cffi>=1.12 in c:\users\niraj\anaconda3\lib\site-packages (from cryptography>=3.4->jwcrypto<2.0.0,>=1.4->fief-client[cli]->codecarbon) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\niraj\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=3.4->jwcrypto<2.0.0,>=1.4->fief-client[cli]->codecarbon) (2.21)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\niraj\anaconda3\lib\site-packages (from pandas->codecarbon) (1.26.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\niraj\anaconda3\lib\site-packages (from pandas->codecarbon) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\niraj\anaconda3\lib\site-packages (from pandas->codecarbon) (2023.3)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\niraj\anaconda3\lib\site-packages (from pydantic->codecarbon) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\niraj\anaconda3\lib\site-packages (from pydantic->codecarbon) (2.20.1)
# Collecting nvidia-ml-py<13.0.0a0,>=12.0.0 (from pynvml->codecarbon)
#   Using cached nvidia_ml_py-12.575.51-py3-none-any.whl.metadata (9.3 kB)
# Requirement already satisfied: prompt_toolkit<4.0,>=2.0 in c:\users\niraj\appdata\roaming\python\python312\site-packages (from questionary->codecarbon) (3.0.47)
# Requirement already satisfied: wcwidth in c:\users\niraj\appdata\roaming\python\python312\site-packages (from prompt_toolkit<4.0,>=2.0->questionary->codecarbon) (0.2.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\niraj\anaconda3\lib\site-packages (from requests->codecarbon) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\niraj\anaconda3\lib\site-packages (from requests->codecarbon) (2.2.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\niraj\anaconda3\lib\site-packages (from rich->codecarbon) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\niraj\appdata\roaming\python\python312\site-packages (from rich->codecarbon) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\niraj\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->codecarbon) (0.1.0)
# Collecting termcolor<2.4.0,>=2.2.0 (from yaspin->fief-client[cli]->codecarbon)
#   Downloading termcolor-2.3.0-py3-none-any.whl.metadata (5.3 kB)
# Downloading codecarbon-3.0.4-py3-none-any.whl (277 kB)
# Downloading fief_client-0.20.0-py3-none-any.whl (20 kB)
# Downloading jwcrypto-1.5.6-py3-none-any.whl (92 kB)
# Using cached pynvml-12.0.0-py3-none-any.whl (26 kB)
# Using cached nvidia_ml_py-12.575.51-py3-none-any.whl (47 kB)
# Downloading questionary-2.1.0-py3-none-any.whl (36 kB)
# Downloading rapidfuzz-3.13.0-cp312-cp312-win_amd64.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.6 MB ? eta -:--:--
#    ------------ --------------------------- 0.5/1.6 MB 1.4 MB/s eta 0:00:01
#    ------------------- -------------------- 0.8/1.6 MB 1.6 MB/s eta 0:00:01
#    ------------------------- -------------- 1.0/1.6 MB 1.4 MB/s eta 0:00:01
#    ------------------------- -------------- 1.0/1.6 MB 1.4 MB/s eta 0:00:01
#    -------------------------------- ------- 1.3/1.6 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 1.2 MB/s  0:00:01
# Downloading yaspin-3.1.0-py3-none-any.whl (18 kB)
# Downloading termcolor-2.3.0-py3-none-any.whl (6.9 kB)
# Installing collected packages: nvidia-ml-py, termcolor, rapidfuzz, pynvml, yaspin, questionary, jwcrypto, fief-client, codecarbon
#
#   Attempting uninstall: termcolor
#
#     Found existing installation: termcolor 3.1.0
#
#     Uninstalling termcolor-3.1.0:
#
#       Successfully uninstalled termcolor-3.1.0
#
#    -------- ------------------------------- 2/9 [rapidfuzz]
#    ------------- -------------------------- 3/9 [pynvml]
#    -------------------------- ------------- 6/9 [jwcrypto]
#    ------------------------------- -------- 7/9 [fief-client]
#    ----------------------------------- ---- 8/9 [codecarbon]
#    ---------------------------------------- 9/9 [codecarbon]
#
# Successfully installed codecarbon-3.0.4 fief-client-0.20.0 jwcrypto-1.5.6 nvidia-ml-py-12.575.51 pynvml-12.0.0 questionary-2.1.0 rapidfuzz-3.13.0 termcolor-2.3.0 yaspin-3.1.0
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.19.0 requires h5py>=3.11.0, which is not installed.

# %%
# !pip uninstall transformers
# !pip install sentence-transformers
# Out:
# ^C
# Requirement already satisfied: sentence-transformers in c:\users\niraj\anaconda3\lib\site-packages (5.0.0)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in c:\users\niraj\anaconda3\lib\site-packages (from sentence-transformers) (4.53.2)
# Requirement already satisfied: tqdm in c:\users\niraj\anaconda3\lib\site-packages (from sentence-transformers) (4.66.5)
# Requirement already satisfied: torch>=1.11.0 in c:\users\niraj\anaconda3\lib\site-packages (from sentence-transformers) (2.7.1)
# Requirement already satisfied: scikit-learn in c:\users\niraj\anaconda3\lib\site-packages (from sentence-transformers) (1.5.1)
# Requirement already satisfied: scipy in c:\users\niraj\anaconda3\lib\site-packages (from sentence-transformers) (1.13.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\niraj\anaconda3\lib\site-packages (from sentence-transformers) (0.33.4)
# Requirement already satisfied: Pillow in c:\users\niraj\anaconda3\lib\site-packages (from sentence-transformers) (10.4.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\niraj\anaconda3\lib\site-packages (from sentence-transformers) (4.14.1)
# Requirement already satisfied: filelock in c:\users\niraj\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (3.13.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\niraj\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\niraj\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\niraj\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\niraj\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.9.11)
# Requirement already satisfied: requests in c:\users\niraj\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\niraj\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.21.2)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\niraj\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.5.3)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\niraj\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2024.6.1)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\niraj\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx in c:\users\niraj\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.3)
# Requirement already satisfied: jinja2 in c:\users\niraj\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.4)
# Requirement already satisfied: setuptools in c:\users\niraj\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (75.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\niraj\anaconda3\lib\site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: colorama in c:\users\niraj\anaconda3\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\niraj\anaconda3\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\niraj\anaconda3\lib\site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\niraj\anaconda3\lib\site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\niraj\anaconda3\lib\site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\niraj\anaconda3\lib\site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (2025.7.14)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\niraj\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\niraj\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers) (3.5.0)

# %%
from sentence_transformers import SentenceTransformer

model = SentenceTransformer("all-MiniLM-L6-v2")

texts = ["The Eiffe77l Tower is in Paris", "Python is a programming language"]
embeddings = model.encode(texts)
print(embeddings)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\niraj\anaconda3\Lib\site-packages\transformers\utils\import_utils.py:2154, in _LazyModule.__getattr__(self, name)
#    2153 try:
# -> 2154     module = self._get_module(self._class_to_module[name])
#    2155     value = getattr(module, name)
#
# File c:\Users\niraj\anaconda3\Lib\site-packages\transformers\utils\import_utils.py:2184, in _LazyModule._get_module(self, module_name)
#    2183 except Exception as e:
# -> 2184     raise e
#
# File c:\Users\niraj\anaconda3\Lib\site-packages\transformers\utils\import_utils.py:2182, in _LazyModule._get_module(self, module_name)
#    2181 try:
# -> 2182     return importlib.import_module("." + module_name, self.__name__)
#    2183 except Exception as e:
#
# File c:\Users\niraj\anaconda3\Lib\importlib\__init__.py:90, in import_module(name, package)
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1331, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:935, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:995, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:488, in _call_with_frames_removed(f, *args, **kwds)
#
# File c:\Users\niraj\anaconda3\Lib\site-packages\transformers\modeling_tf_utils.py:32
#      30 from typing import TYPE_CHECKING, Any, Callable, Optional, Union
# ---> 32 import h5py
#      33 import numpy as np
#
# ModuleNotFoundError: No module named 'h5py'
#
# The above exception was the direct cause of the following exception:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\niraj\anaconda3\Lib\site-packages\transformers\utils\import_utils.py:2154, in _LazyModule.__getattr__(self, name)
#    2153 try:
# -> 2154     module = self._get_module(self._class_to_module[name])
#    2155     value = getattr(module, name)
#
# File c:\Users\niraj\anaconda3\Lib\site-packages\transformers\utils\import_utils.py:2184, in _LazyModule._get_module(self, module_name)
#    2183 except Exception as e:
# -> 2184     raise e
#
# File c:\Users\niraj\anaconda3\Lib\site-packages\transformers\utils\import_utils.py:2182, in _LazyModule._get_module(self, module_name)
#    2181 try:
# -> 2182     return importlib.import_module("." + module_name, self.__name__)
#    2183 except Exception as e:
#
# File c:\Users\niraj\anaconda3\Lib\importlib\__init__.py:90, in import_module(name, package)
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1331, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:935, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:995, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:488, in _call_with_frames_removed(f, *args, **kwds)
#
# File c:\Users\niraj\anaconda3\Lib\site-packages\transformers\integrations\integration_utils.py:37
#      35 import packaging.version
# ---> 37 from .. import PreTrainedModel, TFPreTrainedModel, TrainingArguments
#      38 from .. import __version__ as version
#
# File c:\Users\niraj\anaconda3\Lib\site-packages\transformers\utils\import_utils.py:2157, in _LazyModule.__getattr__(self, name)
#    2156     except (ModuleNotFoundError, RuntimeError) as e:
# -> 2157         raise ModuleNotFoundError(
#    2158             f"Could not import module '{name}'. Are this object's requirements defined correctly?"
#    2159         ) from e
#    2161 elif name in self._modules:
#
# ModuleNotFoundError: Could not import module 'TFPreTrainedModel'. Are this object's requirements defined correctly?
#
# The above exception was the direct cause of the following exception:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from sentence_transformers import SentenceTransformer
#       3 model = SentenceTransformer("all-MiniLM-L6-v2")
#       5 texts = ["The Eiffe77l Tower is in Paris", "Python is a programming language"]
#
# File c:\Users\niraj\anaconda3\Lib\site-packages\sentence_transformers\__init__.py:15
#       8 import warnings
#      10 from sentence_transformers.backend import (
#      11     export_dynamic_quantized_onnx_model,
#      12     export_optimized_onnx_model,
#      13     export_static_quantized_openvino_model,
#      14 )
# ---> 15 from sentence_transformers.cross_encoder import (
#      16     CrossEncoder,
#      17     CrossEncoderModelCardData,
#      18     CrossEncoderTrainer,
#      19     CrossEncoderTrainingArguments,
#      20 )
#      21 from sentence_transformers.datasets import ParallelSentencesDataset, SentencesDataset
#      22 from sentence_transformers.LoggingHandler import LoggingHandler
#
# File c:\Users\niraj\anaconda3\Lib\site-packages\sentence_transformers\cross_encoder\__init__.py:3
#       1 from __future__ import annotations
# ----> 3 from .CrossEncoder import CrossEncoder
#       4 from .model_card import CrossEncoderModelCardData
#       5 from .trainer import CrossEncoderTrainer
#
# File c:\Users\niraj\anaconda3\Lib\site-packages\sentence_transformers\cross_encoder\CrossEncoder.py:31
#      28 from typing_extensions import deprecated
#      30 from sentence_transformers import __version__
# ---> 31 from sentence_transformers.cross_encoder.fit_mixin import FitMixin
#      32 from sentence_transformers.cross_encoder.model_card import CrossEncoderModelCardData, generate_model_card
#      33 from sentence_transformers.cross_encoder.util import (
#      34     cross_encoder_init_args_decorator,
#      35     cross_encoder_predict_rank_args_decorator,
#      36 )
#
# File c:\Users\niraj\anaconda3\Lib\site-packages\sentence_transformers\cross_encoder\fit_mixin.py:20
#      18 from sentence_transformers.cross_encoder.training_args import CrossEncoderTrainingArguments
#      19 from sentence_transformers.datasets.NoDuplicatesDataLoader import NoDuplicatesDataLoader
# ---> 20 from sentence_transformers.datasets.SentenceLabelDataset import SentenceLabelDataset
#      21 from sentence_transformers.evaluation.SentenceEvaluator import SentenceEvaluator
#      22 from sentence_transformers.readers import InputExample
#
# File c:\Users\niraj\anaconda3\Lib\site-packages\sentence_transformers\datasets\__init__.py:13
#      11 from .DenoisingAutoEncoderDataset import DenoisingAutoEncoderDataset
#      12 from .NoDuplicatesDataLoader import NoDuplicatesDataLoader
# ---> 13 from .ParallelSentencesDataset import ParallelSentencesDataset
#      14 from .SentenceLabelDataset import SentenceLabelDataset
#      15 from .SentencesDataset import SentencesDataset
#
# File c:\Users\niraj\anaconda3\Lib\site-packages\sentence_transformers\datasets\ParallelSentencesDataset.py:19
#      15 import random
#      17 from torch.utils.data import Dataset
# ---> 19 from sentence_transformers import SentenceTransformer
#      20 from sentence_transformers.readers import InputExample
#      22 logger = logging.getLogger(__name__)
#
# File c:\Users\niraj\anaconda3\Lib\site-packages\sentence_transformers\SentenceTransformer.py:36
#      33 from transformers.dynamic_module_utils import get_class_from_dynamic_module, get_relative_import_files
#      34 from typing_extensions import deprecated
# ---> 36 from sentence_transformers.model_card import SentenceTransformerModelCardData, generate_model_card
#      37 from sentence_transformers.models import Router
#      38 from sentence_transformers.models.Module import Module
#
# File c:\Users\niraj\anaconda3\Lib\site-packages\sentence_transformers\model_card.py:26
#      24 from tqdm.autonotebook import tqdm
#      25 from transformers import TrainerCallback
# ---> 26 from transformers.integrations import CodeCarbonCallback
#      27 from transformers.modelcard import make_markdown_table
#      28 from transformers.trainer_callback import TrainerControl, TrainerState
#
# File c:\Users\niraj\anaconda3\Lib\site-packages\transformers\utils\import_utils.py:2157, in _LazyModule.__getattr__(self, name)
#    2155         value = getattr(module, name)
#    2156     except (ModuleNotFoundError, RuntimeError) as e:
# -> 2157         raise ModuleNotFoundError(
#    2158             f"Could not import module '{name}'. Are this object's requirements defined correctly?"
#    2159         ) from e
#    2161 elif name in self._modules:
#    2162     try:
#
# ModuleNotFoundError: Could not import module 'CodeCarbonCallback'. Are this object's requirements defined correctly?
